# %%
# %run _bootstrap.py
from src.paths import DATA_ROOT

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import glob

# Define paths (using DATA_ROOT for portability)
PERMITS_BASE = DATA_ROOT / "data" / "dewey_permits_builty" / "dewey-downloads"
CONDO_REF_PATH = DATA_ROOT / "final_datasets" / "attom_all_condo_units_basic_info.dta"

# Folders
folders = [
    PERMITS_BASE / "florida-permits-miami-broward",
    PERMITS_BASE / "florida-permits-ex-miami-broward"
]

# Count parquet files
total_files = sum(len(list(f.glob("*.parquet"))) for f in folders)
print(f"Total parquet files to process: {total_files}")

# Explore one file from each folder to understand schema
for folder in folders:
    sample_file = list(folder.glob("*.parquet"))[0]
    print(f"\n--- {folder.name} ---")
    print(f"Sample file: {sample_file.name}")
    
    df_sample = pd.read_parquet(sample_file)
    print(f"Shape: {df_sample.shape}")
    print(f"Columns: {df_sample.columns.tolist()}")
    print(f"First row sample (address columns):")
    addr_cols = [c for c in df_sample.columns if any(x in c.lower() for x in ['addr', 'street', 'city', 'zip'])]
    if addr_cols:
        print(df_sample[addr_cols].head(1).to_string())
# Out:
# Total parquet files to process: 193
#
# --- florida-permits-miami-broward ---
# Sample file: building-permits-united-states_0_0_0.snappy.parquet
# Shape: (231907, 88)
# Columns: ['ACCESSORY_STRUCTURE', 'ACCESSORY_STRUCTURE_TYPE', 'AIR_SOURCE_HEAT_PUMP', 'APN', 'APPLICANT_CITY', 'APPLICANT_STATE', 'APPLICANT_ZIPCODE', 'ATTACHED_DETACHED', 'BATH_ITEMS_INSTALLED', 'BATH_REMODEL', 'CITY', 'COMMERCIAL', 'CONDITION', 'CONSTRUCTION_TYPE', 'COUNTY', 'COUNTY_FIPS', 'DATA', 'DEMOLITION', 'DEMO_FULL_PARTIAL', 'DESCRIPTION', 'DWELLING_TYPE', 'EFFICIENCY', 'ELECTRICAL_PANEL_UPGRADE', 'ELECTRICAL_SERVICE_UPGRADE', 'EV_CHARGER', 'EXTERIOR_REMODEL', 'EXTERIOR_REMODEL_TYPE', 'FILE_DATE', 'FINAL_DATE', 'FOUNDATION', 'FOUNDATION_TYPE', 'FOUNDATION_WORK_TYPE', 'GROUND_SOURCE_HEAT_PUMP', 'HEAT_PUMP_WATER_HEATER', 'INDUCTION_STOVE', 'JOB_VALUE', 'JURISDICTION', 'KITCHEN_ITEMS_INSTALLED', 'KITCHEN_REMODEL', 'MULTIFAMILY', 'NEW_ADU', 'NEW_DWELLING', 'NUM_BATHS', 'NUM_BEDS', 'NUM_BUILDINGS', 'NUM_DOORS', 'NUM_FLOORS', 'NUM_ROOMS', 'NUM_UNITS', 'NUM_WINDOWS', 'OWNER_CITY', 'OWNER_STATE', 'OWNER_ZIPCODE', 'PERMIT_DATE', 'PERMIT_NUMBER', 'POOL_SPA', 'POOL_TYPE', 'PUBLIC_WORK', 'RECORD_SUBTYPE_ORIGINAL', 'RECORD_TYPE_ORIGINAL', 'REMODEL_MATERIALS_USED', 'REROOF', 'REROOF_MATERIAL', 'REROOF_TYPE', 'RESIDENTIAL', 'ROOM_ADDITION', 'ROOM_ADDITION_TYPE', 'SITEWORK', 'SITEWORK_TYPE', 'SIZE_SQUARES', 'SIZE_SQUARE_FEET', 'SOLAR', 'SOLAR_BATTERY_STORAGE', 'STATE', 'STATE_FIPS', 'STATUS_NORMALIZED', 'STATUS_ORIGINAL', 'STREET', 'TENANT_IMPROVEMENT', 'TOTAL_FEES', 'UTILITIES', 'UTILITY_CAPACITY', 'UTILITY_TYPE', 'VOLUME', 'WIND', 'WINDOW_DOOR', 'WINDOW_DOOR_TYPE', 'ZIPCODE']
# First row sample (address columns):
#   APPLICANT_CITY APPLICANT_ZIPCODE         CITY OWNER_CITY OWNER_ZIPCODE            STREET UTILITY_CAPACITY ZIPCODE
# 0           None              None  Miami Beach       None          None  7832 Collins Ave             None   33141
#
# --- florida-permits-ex-miami-broward ---
# Sample file: building-permits-united-states_0_0_0.snappy.parquet
# Shape: (458270, 88)
# Columns: ['ACCESSORY_STRUCTURE', 'ACCESSORY_STRUCTURE_TYPE', 'AIR_SOURCE_HEAT_PUMP', 'APN', 'APPLICANT_CITY', 'APPLICANT_STATE', 'APPLICANT_ZIPCODE', 'ATTACHED_DETACHED', 'BATH_ITEMS_INSTALLED', 'BATH_REMODEL', 'CITY', 'COMMERCIAL', 'CONDITION', 'CONSTRUCTION_TYPE', 'COUNTY', 'COUNTY_FIPS', 'DATA', 'DEMOLITION', 'DEMO_FULL_PARTIAL', 'DESCRIPTION', 'DWELLING_TYPE', 'EFFICIENCY', 'ELECTRICAL_PANEL_UPGRADE', 'ELECTRICAL_SERVICE_UPGRADE', 'EV_CHARGER', 'EXTERIOR_REMODEL', 'EXTERIOR_REMODEL_TYPE', 'FILE_DATE', 'FINAL_DATE', 'FOUNDATION', 'FOUNDATION_TYPE', 'FOUNDATION_WORK_TYPE', 'GROUND_SOURCE_HEAT_PUMP', 'HEAT_PUMP_WATER_HEATER', 'INDUCTION_STOVE', 'JOB_VALUE', 'JURISDICTION', 'KITCHEN_ITEMS_INSTALLED', 'KITCHEN_REMODEL', 'MULTIFAMILY', 'NEW_ADU', 'NEW_DWELLING', 'NUM_BATHS', 'NUM_BEDS', 'NUM_BUILDINGS', 'NUM_DOORS', 'NUM_FLOORS', 'NUM_ROOMS', 'NUM_UNITS', 'NUM_WINDOWS', 'OWNER_CITY', 'OWNER_STATE', 'OWNER_ZIPCODE', 'PERMIT_DATE', 'PERMIT_NUMBER', 'POOL_SPA', 'POOL_TYPE', 'PUBLIC_WORK', 'RECORD_SUBTYPE_ORIGINAL', 'RECORD_TYPE_ORIGINAL', 'REMODEL_MATERIALS_USED', 'REROOF', 'REROOF_MATERIAL', 'REROOF_TYPE', 'RESIDENTIAL', 'ROOM_ADDITION', 'ROOM_ADDITION_TYPE', 'SITEWORK', 'SITEWORK_TYPE', 'SIZE_SQUARES', 'SIZE_SQUARE_FEET', 'SOLAR', 'SOLAR_BATTERY_STORAGE', 'STATE', 'STATE_FIPS', 'STATUS_NORMALIZED', 'STATUS_ORIGINAL', 'STREET', 'TENANT_IMPROVEMENT', 'TOTAL_FEES', 'UTILITIES', 'UTILITY_CAPACITY', 'UTILITY_TYPE', 'VOLUME', 'WIND', 'WINDOW_DOOR', 'WINDOW_DOOR_TYPE', 'ZIPCODE']
# First row sample (address columns):
#   APPLICANT_CITY APPLICANT_ZIPCODE   CITY OWNER_CITY OWNER_ZIPCODE             STREET UTILITY_CAPACITY ZIPCODE
# 0           None              None  Tampa      Tampa         33602  705 W Columbus Dr             None   33602

# %%
# Load and inspect the condo reference dataset (Stata file)
print("--- Condo Reference Dataset ---")
condo_ref = pd.read_stata(CONDO_REF_PATH)
print(f"Shape: {condo_ref.shape}")
print(f"Columns: {condo_ref.columns.tolist()}")

# Check what address-related columns are available
addr_cols = [c for c in condo_ref.columns if any(x in c.lower() for x in ['addr', 'address', 'street', 'city', 'zip'])]
print(f"\nAddress-related columns in condo ref: {addr_cols}")

if addr_cols:
    print(f"\nSample address data:")
    print(condo_ref[addr_cols].head(3))
# Out:
# --- Condo Reference Dataset ---
# Shape: (1556817, 10)
# Columns: ['id_attom', 'mm_fips_county_name_attom', 'sa_nbr_bath_attom', 'sa_nbr_bedrms_attom', 'sa_sqft_attom', 'sa_x_coord_attom', 'sa_y_coord_attom', 'address_attom', 'building_address_attom', 'flag_80pct_same_coords_building']
#
# Address-related columns in condo ref: ['address_attom', 'building_address_attom']
#
# Sample address data:
#                             address_attom               building_address_attom
# 0   008 CONFIDENTIAL 8, ORLANDO, FL 32812  008 CONFIDENTIAL, ORLANDO, FL 32812
# 1     010 CONFIDENTIAL, ORLANDO, FL 32806  010 CONFIDENTIAL, ORLANDO, FL 32806
# 2  024 CONFIDENTIAL 24, ORLANDO, FL 32822  024 CONFIDENTIAL, ORLANDO, FL 32822

# %%
# Load a sample permit file to inspect address columns
sample_permit = pd.read_parquet(list(folders[0].glob("*.parquet"))[0])
print("--- Permits Data Structure ---")
print(f"Shape: {sample_permit.shape}")
print(f"\nAll columns:")
for i, col in enumerate(sample_permit.columns, 1):
    print(f"  {i:2d}. {col}")

# Show all address-related columns
print(f"\n--- Address-related columns in permits ---")
addr_cols = [c for c in sample_permit.columns if any(x in c.lower() for x in ['addr', 'address', 'street', 'city', 'zip', 'location'])]
print(f"Found: {addr_cols}")

if addr_cols:
    print(f"\nSample data (first 3 rows):")
    print(sample_permit[addr_cols].head(3).to_string())
    
    print(f"\n--- Data types ---")
    print(sample_permit[addr_cols].dtypes)
# Out:
# --- Permits Data Structure ---
# Shape: (231907, 88)
#
# All columns:
#    1. ACCESSORY_STRUCTURE
#    2. ACCESSORY_STRUCTURE_TYPE
#    3. AIR_SOURCE_HEAT_PUMP
#    4. APN
#    5. APPLICANT_CITY
#    6. APPLICANT_STATE
#    7. APPLICANT_ZIPCODE
#    8. ATTACHED_DETACHED
#    9. BATH_ITEMS_INSTALLED
#   10. BATH_REMODEL
#   11. CITY
#   12. COMMERCIAL
#   13. CONDITION
#   14. CONSTRUCTION_TYPE
#   15. COUNTY
#   16. COUNTY_FIPS
#   17. DATA
#   18. DEMOLITION
#   19. DEMO_FULL_PARTIAL
#   20. DESCRIPTION
#   21. DWELLING_TYPE
#   22. EFFICIENCY
#   23. ELECTRICAL_PANEL_UPGRADE
#   24. ELECTRICAL_SERVICE_UPGRADE
#   25. EV_CHARGER
#   26. EXTERIOR_REMODEL
#   27. EXTERIOR_REMODEL_TYPE
#   28. FILE_DATE
#   29. FINAL_DATE
#   30. FOUNDATION
#   31. FOUNDATION_TYPE
#   32. FOUNDATION_WORK_TYPE
#   33. GROUND_SOURCE_HEAT_PUMP
#   34. HEAT_PUMP_WATER_HEATER
#   35. INDUCTION_STOVE
#   36. JOB_VALUE
#   37. JURISDICTION
#   38. KITCHEN_ITEMS_INSTALLED
#   39. KITCHEN_REMODEL
#   40. MULTIFAMILY
#   41. NEW_ADU
#   42. NEW_DWELLING
#   43. NUM_BATHS
#   44. NUM_BEDS
#   45. NUM_BUILDINGS
#   46. NUM_DOORS
#   47. NUM_FLOORS
#   48. NUM_ROOMS
#   49. NUM_UNITS
#   50. NUM_WINDOWS
#   51. OWNER_CITY
#   52. OWNER_STATE
#   53. OWNER_ZIPCODE
#   54. PERMIT_DATE
#   55. PERMIT_NUMBER
#   56. POOL_SPA
#   57. POOL_TYPE
#   58. PUBLIC_WORK
#   59. RECORD_SUBTYPE_ORIGINAL
#   60. RECORD_TYPE_ORIGINAL
#   61. REMODEL_MATERIALS_USED
#   62. REROOF
#   63. REROOF_MATERIAL
#   64. REROOF_TYPE
#   65. RESIDENTIAL
#   66. ROOM_ADDITION
#   67. ROOM_ADDITION_TYPE
#   68. SITEWORK
#   69. SITEWORK_TYPE
#   70. SIZE_SQUARES
#   71. SIZE_SQUARE_FEET
#   72. SOLAR
#   73. SOLAR_BATTERY_STORAGE
#   74. STATE
#   75. STATE_FIPS
#   76. STATUS_NORMALIZED
#   77. STATUS_ORIGINAL
#   78. STREET
#   79. TENANT_IMPROVEMENT
#   80. TOTAL_FEES
#   81. UTILITIES
#   82. UTILITY_CAPACITY
#   83. UTILITY_TYPE
#   84. VOLUME
#   85. WIND
#   86. WINDOW_DOOR
#   87. WINDOW_DOOR_TYPE
#   88. ZIPCODE
#
# --- Address-related columns in permits ---
# Found: ['APPLICANT_CITY', 'APPLICANT_ZIPCODE', 'CITY', 'OWNER_CITY', 'OWNER_ZIPCODE', 'STREET', 'UTILITY_CAPACITY', 'ZIPCODE']
#
# Sample data (first 3 rows):
#   APPLICANT_CITY APPLICANT_ZIPCODE         CITY OWNER_CITY OWNER_ZIPCODE            STREET UTILITY_CAPACITY ZIPCODE
# 0           None              None  Miami Beach       None          None  7832 Collins Ave             None   33141
# 1           None              None  Miami Beach       None          None     824 W W 47 St             None   33140
# 2           None              None  Miami Beach       None          None     1244 Ocean Dr             None   33139
#
# --- Data types ---
# APPLICANT_CITY       object
# APPLICANT_ZIPCODE    object
# CITY                 object
# OWNER_CITY           object
# OWNER_ZIPCODE        object
# STREET               object
# UTILITY_CAPACITY     object
# ZIPCODE              object
# dtype: object

# %%
# Build address from permits: STREET + CITY + STATE + ZIPCODE
def build_permit_address(row):
    """Construct full address from permit components."""
    parts = []
    if pd.notna(row.get('STREET')):
        parts.append(str(row['STREET']).strip().upper())
    if pd.notna(row.get('CITY')):
        parts.append(str(row['CITY']).strip().upper())
    if pd.notna(row.get('STATE')):
        parts.append(str(row['STATE']).strip().upper())
    if pd.notna(row.get('ZIPCODE')):
        parts.append(str(row['ZIPCODE']).strip())
    
    return ", ".join(parts) if parts else None

# Test on sample
sample_permit['permit_address'] = sample_permit.apply(build_permit_address, axis=1)
print("Sample permit addresses (first 5):")
print(sample_permit[['STREET', 'CITY', 'STATE', 'ZIPCODE', 'permit_address']].head(5))

# Check for matches with condo ref
print(f"\n--- Merge Strategy ---")
print(f"Condo ref: {len(condo_ref):,} records with 'building_address_attom'")
print(f"Permits: {len(sample_permit):,} records with constructed 'permit_address'")

# Quick sample match check
condo_addrs = set(condo_ref['building_address_attom'].dropna())
permit_addrs = set(sample_permit['permit_address'].dropna())
overlap = condo_addrs.intersection(permit_addrs)
print(f"\nAddresses in common (this sample file): {len(overlap)}")
if overlap:
    print(f"Examples: {list(overlap)[:3]}")
# Out:
# Sample permit addresses (first 5):
#              STREET         CITY STATE ZIPCODE  \
# 0  7832 Collins Ave  Miami Beach    FL   33141
# 1     824 W W 47 St  Miami Beach    FL   33140
# 2     1244 Ocean Dr  Miami Beach    FL   33139
# 3      300 Alton Rd  Miami Beach    FL   33139
# 4  1001 Collins Ave  Miami Beach    FL   33139
#
#                              permit_address
# 0  7832 COLLINS AVE, MIAMI BEACH, FL, 33141
# 1     824 W W 47 ST, MIAMI BEACH, FL, 33140
# 2     1244 OCEAN DR, MIAMI BEACH, FL, 33139
# 3      300 ALTON RD, MIAMI BEACH, FL, 33139
# 4  1001 COLLINS AVE, MIAMI BEACH, FL, 33139
#
# --- Merge Strategy ---
# Condo ref: 1,556,817 records with 'building_address_attom'
# Permits: 231,907 records with constructed 'permit_address'
#
# Addresses in common (this sample file): 0

# %%
# Debug: Look at actual condo addresses for Miami Beach (same city as sample permits)
print("--- Condo addresses from Miami Beach ---")
mb_condos = condo_ref[condo_ref['building_address_attom'].str.contains('MIAMI BEACH', case=False, na=False)]
print(f"Found {len(mb_condos)} condos in Miami Beach")
print("\nSample condo addresses:")
print(mb_condos['building_address_attom'].head(10).values)

print("\n--- Permit addresses from Miami Beach (from sample file) ---")
mb_permits = sample_permit[sample_permit['CITY'].str.contains('Miami Beach', case=False, na=False)]
print(f"Found {len(mb_permits)} permits in Miami Beach")
print("\nSample permit addresses:")
print(mb_permits['permit_address'].head(10).values)

# Try matching on just street + city (without state/zip)
print("\n--- Testing Street + City match only ---")
def build_permit_address_simple(row):
    parts = []
    if pd.notna(row.get('STREET')):
        parts.append(str(row['STREET']).strip().upper())
    if pd.notna(row.get('CITY')):
        parts.append(str(row['CITY']).strip().upper())
    return ", ".join(parts) if parts else None

sample_permit['permit_addr_simple'] = sample_permit.apply(build_permit_address_simple, axis=1)

# Extract street + city from condo addresses (before the comma + state + zip)
def extract_street_city_from_condo(addr):
    if pd.isna(addr):
        return None
    # Format appears to be: NUMBER ADDRESS, CITY, STATE ZIP
    # Try to get: ADDRESS, CITY
    parts = str(addr).split(',')
    if len(parts) >= 2:
        return f"{parts[0].strip()}, {parts[1].strip()}".upper()
    return None

condo_ref['addr_simple'] = condo_ref['building_address_attom'].apply(extract_street_city_from_condo)

mb_condos = condo_ref[condo_ref['building_address_attom'].str.contains('MIAMI BEACH', case=False, na=False)]
print(f"Condo simple addresses sample:")
print(mb_condos['addr_simple'].head(10).values)

mb_permits = sample_permit[sample_permit['CITY'].str.contains('Miami Beach', case=False, na=False)]
print(f"\nPermit simple addresses sample:")
print(mb_permits['permit_addr_simple'].head(10).values)

# Check overlap
condo_simple = set(condo_ref['addr_simple'].dropna())
permit_simple = set(sample_permit['permit_addr_simple'].dropna())
overlap_simple = condo_simple.intersection(permit_simple)
print(f"\nMatches on street + city: {len(overlap_simple)}")
if overlap_simple:
    print(f"Examples: {list(overlap_simple)[:5]}")
# Out:
# --- Condo addresses from Miami Beach ---
# Found 53630 condos in Miami Beach
#
# Sample condo addresses:
# ['1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139'
#  '1 CENTURY LN, MIAMI BEACH, FL 33139']
#
# --- Permit addresses from Miami Beach (from sample file) ---
# Found 26111 permits in Miami Beach
#
# Sample permit addresses:
# ['7832 COLLINS AVE, MIAMI BEACH, FL, 33141'
#  '824 W W 47 ST, MIAMI BEACH, FL, 33140'
#  '1244 OCEAN DR, MIAMI BEACH, FL, 33139'
#  '300 ALTON RD, MIAMI BEACH, FL, 33139'
#  '1001 COLLINS AVE, MIAMI BEACH, FL, 33139'
#  '738 LINCOLN RD, MIAMI BEACH, FL, 33139'
#  '220 COLLINS AVE, MIAMI BEACH, FL, 33139'
#  '3127 INDIAN CREEK DR, MIAMI BEACH, FL, 33140'
#  '605 LINCOLN RD, MIAMI BEACH, FL, 33139'
#  '100 S S POINTE DR 3803, MIAMI BEACH, FL, -3313']
#
# --- Testing Street + City match only ---
# Condo simple addresses sample:
# ['1 CENTURY LN, MIAMI BEACH' '1 CENTURY LN, MIAMI BEACH'
#  '1 CENTURY LN, MIAMI BEACH' '1 CENTURY LN, MIAMI BEACH'
#  '1 CENTURY LN, MIAMI BEACH' '1 CENTURY LN, MIAMI BEACH'
#  '1 CENTURY LN, MIAMI BEACH' '1 CENTURY LN, MIAMI BEACH'
#  '1 CENTURY LN, MIAMI BEACH' '1 CENTURY LN, MIAMI BEACH']
#
# Permit simple addresses sample:
# ['7832 COLLINS AVE, MIAMI BEACH' '824 W W 47 ST, MIAMI BEACH'
#  '1244 OCEAN DR, MIAMI BEACH' '300 ALTON RD, MIAMI BEACH'
#  '1001 COLLINS AVE, MIAMI BEACH' '738 LINCOLN RD, MIAMI BEACH'
#  '220 COLLINS AVE, MIAMI BEACH' '3127 INDIAN CREEK DR, MIAMI BEACH'
#  '605 LINCOLN RD, MIAMI BEACH' '100 S S POINTE DR 3803, MIAMI BEACH']
#
# Matches on street + city: 3394
# Examples: ['7403 FAIRFAX DR, TAMARAC', '1775 N ANDREWS SQ, FORT LAUDERDALE', '493 DURHAM Q, DEERFIELD BEACH', '7521 GRANVILLE DR, TAMARAC', '38 PRESCOTT B, DEERFIELD BEACH']

# %%
# Create output directory for condo-only permit subsets
OUTPUT_DIR = DATA_ROOT / "data" / "dewey_permits_builty" / "condo_filtered"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Update address key to include ZIP code: street + city + zip
def build_addr_key_with_zip(addr_simple, zipcode):
    """Combine street+city with zip code for matching."""
    if pd.isna(addr_simple) or pd.isna(zipcode):
        return None
    return f"{addr_simple}, {str(zipcode).strip()}"

# Add ZIP to condo lookup key
condo_ref['addr_key'] = condo_ref.apply(
    lambda row: build_addr_key_with_zip(row['addr_simple'], 
                                        row['building_address_attom'].split(',')[-1].split()[-1] if pd.notna(row['building_address_attom']) else None),
    axis=1
)

# Build lookup table from condo ref: street+city+zip -> list of condo records
condo_lookup = {}
for idx, row in condo_ref.iterrows():
    addr_key = row['addr_key']
    if pd.notna(addr_key):
        if addr_key not in condo_lookup:
            condo_lookup[addr_key] = []
        condo_lookup[addr_key].append(row.to_dict())

print(f"Built lookup table: {len(condo_lookup):,} unique street+city+zip combinations")

# Merge function: takes permit dataframe, returns only rows that match condo addresses
def filter_permits_to_condos(permit_df):
    """Filter permit records to only those matching condo addresses (street+city+zip)."""
    permit_df = permit_df.copy()
    permit_df['permit_addr_simple'] = permit_df.apply(build_permit_address_simple, axis=1)
    permit_df['permit_addr_key'] = permit_df.apply(
        lambda row: build_addr_key_with_zip(row['permit_addr_simple'], row['ZIPCODE']),
        axis=1
    )
    
    # Filter to only rows with matches
    matched = permit_df[permit_df['permit_addr_key'].isin(condo_lookup.keys())].copy()
    return matched

# Process all permits in batches
print(f"\n--- Processing {total_files} permit files ---")
total_matched = 0
file_count = 0

for folder in folders:
    print(f"\n{folder.name}:")
    parquet_files = sorted(folder.glob("*.parquet"))
    
    for parquet_file in parquet_files:
        file_count += 1
        
        # Load permit file
        permit_df = pd.read_parquet(parquet_file)
        
        # Filter to condo addresses
        matched_df = filter_permits_to_condos(permit_df)
        matched_count = len(matched_df)
        
        if matched_count > 0:
            # Write filtered output
            output_file = OUTPUT_DIR / f"condo_permits_{file_count:03d}_{parquet_file.stem}.parquet"
            matched_df.to_parquet(output_file)
            total_matched += matched_count
            print(f"  File {file_count:3d}/{total_files} ({parquet_file.name}): {matched_count:7,} matched → {output_file.name}")
        else:
            print(f"  File {file_count:3d}/{total_files} ({parquet_file.name}): 0 matched (skipped)")

print(f"\n--- SUMMARY ---")
print(f"Processed: {file_count} files")
print(f"Total condo-matching permits: {total_matched:,}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Output files: {len(list(OUTPUT_DIR.glob('*.parquet')))}")
# Out:
# Built lookup table: 351,723 unique street+city+zip combinations
#
# --- Processing 193 permit files ---
#
# florida-permits-miami-broward:
#   File   1/193 (building-permits-united-states_0_0_0.snappy.parquet):   8,788 matched → condo_permits_001_building-permits-united-states_0_0_0.snappy.parquet
#   File   2/193 (building-permits-united-states_0_1_0.snappy.parquet):  14,738 matched → condo_permits_002_building-permits-united-states_0_1_0.snappy.parquet
#   File   3/193 (building-permits-united-states_0_1_1.snappy.parquet):      11 matched → condo_permits_003_building-permits-united-states_0_1_1.snappy.parquet
#   File   4/193 (building-permits-united-states_0_2_0.snappy.parquet):   9,111 matched → condo_permits_004_building-permits-united-states_0_2_0.snappy.parquet
#   File   5/193 (building-permits-united-states_0_3_0.snappy.parquet):   7,504 matched → condo_permits_005_building-permits-united-states_0_3_0.snappy.parquet
#   File   6/193 (building-permits-united-states_0_4_0.snappy.parquet):   4,818 matched → condo_permits_006_building-permits-united-states_0_4_0.snappy.parquet
#   File   7/193 (building-permits-united-states_0_5_0.snappy.parquet):   4,062 matched → condo_permits_007_building-permits-united-states_0_5_0.snappy.parquet
#   File   8/193 (building-permits-united-states_0_6_0.snappy.parquet):   5,375 matched → condo_permits_008_building-permits-united-states_0_6_0.snappy.parquet
#   File   9/193 (building-permits-united-states_0_7_0.snappy.parquet):  12,186 matched → condo_permits_009_building-permits-united-states_0_7_0.snappy.parquet
#   File  10/193 (building-permits-united-states_1_0_0.snappy.parquet):     744 matched → condo_permits_010_building-permits-united-states_1_0_0.snappy.parquet
#   File  11/193 (building-permits-united-states_1_1_0.snappy.parquet):  14,128 matched → condo_permits_011_building-permits-united-states_1_1_0.snappy.parquet
#   File  12/193 (building-permits-united-states_1_2_0.snappy.parquet):   7,436 matched → condo_permits_012_building-permits-united-states_1_2_0.snappy.parquet
#   File  13/193 (building-permits-united-states_1_3_0.snappy.parquet):   8,112 matched → condo_permits_013_building-permits-united-states_1_3_0.snappy.parquet
#   File  14/193 (building-permits-united-states_1_4_0.snappy.parquet):  12,656 matched → condo_permits_014_building-permits-united-states_1_4_0.snappy.parquet
#   File  15/193 (building-permits-united-states_1_5_0.snappy.parquet):   5,108 matched → condo_permits_015_building-permits-united-states_1_5_0.snappy.parquet
#   File  16/193 (building-permits-united-states_1_6_0.snappy.parquet):  14,075 matched → condo_permits_016_building-permits-united-states_1_6_0.snappy.parquet
#   File  17/193 (building-permits-united-states_1_7_0.snappy.parquet):  11,687 matched → condo_permits_017_building-permits-united-states_1_7_0.snappy.parquet
#   File  18/193 (building-permits-united-states_2_0_0.snappy.parquet):   8,055 matched → condo_permits_018_building-permits-united-states_2_0_0.snappy.parquet
#   File  19/193 (building-permits-united-states_2_1_0.snappy.parquet):   2,864 matched → condo_permits_019_building-permits-united-states_2_1_0.snappy.parquet
#   File  20/193 (building-permits-united-states_2_2_0.snappy.parquet):   9,348 matched → condo_permits_020_building-permits-united-states_2_2_0.snappy.parquet
#   File  21/193 (building-permits-united-states_2_3_0.snappy.parquet):  10,894 matched → condo_permits_021_building-permits-united-states_2_3_0.snappy.parquet
#   File  22/193 (building-permits-united-states_2_4_0.snappy.parquet):   8,273 matched → condo_permits_022_building-permits-united-states_2_4_0.snappy.parquet
#   File  23/193 (building-permits-united-states_2_5_0.snappy.parquet):   9,138 matched → condo_permits_023_building-permits-united-states_2_5_0.snappy.parquet
#   File  24/193 (building-permits-united-states_2_6_0.snappy.parquet):  10,533 matched → condo_permits_024_building-permits-united-states_2_6_0.snappy.parquet
#   File  25/193 (building-permits-united-states_2_7_0.snappy.parquet):   4,278 matched → condo_permits_025_building-permits-united-states_2_7_0.snappy.parquet
#   File  26/193 (building-permits-united-states_3_0_0.snappy.parquet):   3,158 matched → condo_permits_026_building-permits-united-states_3_0_0.snappy.parquet
#   File  27/193 (building-permits-united-states_3_1_0.snappy.parquet):   3,541 matched → condo_permits_027_building-permits-united-states_3_1_0.snappy.parquet
#   File  28/193 (building-permits-united-states_3_2_0.snappy.parquet):   4,698 matched → condo_permits_028_building-permits-united-states_3_2_0.snappy.parquet
#   File  29/193 (building-permits-united-states_3_3_0.snappy.parquet):   7,117 matched → condo_permits_029_building-permits-united-states_3_3_0.snappy.parquet
#   File  30/193 (building-permits-united-states_3_4_0.snappy.parquet):   1,625 matched → condo_permits_030_building-permits-united-states_3_4_0.snappy.parquet
#   File  31/193 (building-permits-united-states_3_5_0.snappy.parquet):   3,881 matched → condo_permits_031_building-permits-united-states_3_5_0.snappy.parquet
#   File  32/193 (building-permits-united-states_3_6_0.snappy.parquet):   7,359 matched → condo_permits_032_building-permits-united-states_3_6_0.snappy.parquet
#   File  33/193 (building-permits-united-states_3_7_0.snappy.parquet):  14,150 matched → condo_permits_033_building-permits-united-states_3_7_0.snappy.parquet
#
# florida-permits-ex-miami-broward:
#   File  34/193 (building-permits-united-states_0_0_0.snappy.parquet):   2,217 matched → condo_permits_034_building-permits-united-states_0_0_0.snappy.parquet
#   File  35/193 (building-permits-united-states_0_0_1.snappy.parquet):   7,663 matched → condo_permits_035_building-permits-united-states_0_0_1.snappy.parquet
#   File  36/193 (building-permits-united-states_0_0_2.snappy.parquet):   5,239 matched → condo_permits_036_building-permits-united-states_0_0_2.snappy.parquet
#   File  37/193 (building-permits-united-states_0_0_3.snappy.parquet):     162 matched → condo_permits_037_building-permits-united-states_0_0_3.snappy.parquet
#   File  38/193 (building-permits-united-states_0_1_0.snappy.parquet):   1,520 matched → condo_permits_038_building-permits-united-states_0_1_0.snappy.parquet
#   File  39/193 (building-permits-united-states_0_1_1.snappy.parquet):   3,255 matched → condo_permits_039_building-permits-united-states_0_1_1.snappy.parquet
#   File  40/193 (building-permits-united-states_0_1_2.snappy.parquet):   2,341 matched → condo_permits_040_building-permits-united-states_0_1_2.snappy.parquet
#   File  41/193 (building-permits-united-states_0_1_3.snappy.parquet):   3,346 matched → condo_permits_041_building-permits-united-states_0_1_3.snappy.parquet
#   File  42/193 (building-permits-united-states_0_1_4.snappy.parquet):     374 matched → condo_permits_042_building-permits-united-states_0_1_4.snappy.parquet
#   File  43/193 (building-permits-united-states_0_2_0.snappy.parquet):   3,099 matched → condo_permits_043_building-permits-united-states_0_2_0.snappy.parquet
#   File  44/193 (building-permits-united-states_0_2_1.snappy.parquet):   9,364 matched → condo_permits_044_building-permits-united-states_0_2_1.snappy.parquet
#   File  45/193 (building-permits-united-states_0_2_2.snappy.parquet):   4,920 matched → condo_permits_045_building-permits-united-states_0_2_2.snappy.parquet
#   File  46/193 (building-permits-united-states_0_2_3.snappy.parquet):   3,210 matched → condo_permits_046_building-permits-united-states_0_2_3.snappy.parquet
#   File  47/193 (building-permits-united-states_0_2_4.snappy.parquet):   2,439 matched → condo_permits_047_building-permits-united-states_0_2_4.snappy.parquet
#   File  48/193 (building-permits-united-states_0_3_0.snappy.parquet):   5,624 matched → condo_permits_048_building-permits-united-states_0_3_0.snappy.parquet
#   File  49/193 (building-permits-united-states_0_3_1.snappy.parquet):   2,556 matched → condo_permits_049_building-permits-united-states_0_3_1.snappy.parquet
#   File  50/193 (building-permits-united-states_0_3_2.snappy.parquet):   3,798 matched → condo_permits_050_building-permits-united-states_0_3_2.snappy.parquet
#   File  51/193 (building-permits-united-states_0_3_3.snappy.parquet):   3,073 matched → condo_permits_051_building-permits-united-states_0_3_3.snappy.parquet
#   File  52/193 (building-permits-united-states_0_3_4.snappy.parquet):     480 matched → condo_permits_052_building-permits-united-states_0_3_4.snappy.parquet
#   File  53/193 (building-permits-united-states_0_4_0.snappy.parquet):   2,985 matched → condo_permits_053_building-permits-united-states_0_4_0.snappy.parquet
#   File  54/193 (building-permits-united-states_0_4_1.snappy.parquet):   3,370 matched → condo_permits_054_building-permits-united-states_0_4_1.snappy.parquet
#   File  55/193 (building-permits-united-states_0_4_2.snappy.parquet):  10,802 matched → condo_permits_055_building-permits-united-states_0_4_2.snappy.parquet
#   File  56/193 (building-permits-united-states_0_4_3.snappy.parquet):   2,696 matched → condo_permits_056_building-permits-united-states_0_4_3.snappy.parquet
#   File  57/193 (building-permits-united-states_0_4_4.snappy.parquet): 0 matched (skipped)
#   File  58/193 (building-permits-united-states_0_5_0.snappy.parquet):   6,997 matched → condo_permits_058_building-permits-united-states_0_5_0.snappy.parquet
#   File  59/193 (building-permits-united-states_0_5_1.snappy.parquet):   3,374 matched → condo_permits_059_building-permits-united-states_0_5_1.snappy.parquet
#   File  60/193 (building-permits-united-states_0_5_2.snappy.parquet):   6,109 matched → condo_permits_060_building-permits-united-states_0_5_2.snappy.parquet
#   File  61/193 (building-permits-united-states_0_5_3.snappy.parquet):   4,829 matched → condo_permits_061_building-permits-united-states_0_5_3.snappy.parquet
#   File  62/193 (building-permits-united-states_0_6_0.snappy.parquet):   2,783 matched → condo_permits_062_building-permits-united-states_0_6_0.snappy.parquet
#   File  63/193 (building-permits-united-states_0_6_1.snappy.parquet):   2,913 matched → condo_permits_063_building-permits-united-states_0_6_1.snappy.parquet
#   File  64/193 (building-permits-united-states_0_6_2.snappy.parquet):   3,847 matched → condo_permits_064_building-permits-united-states_0_6_2.snappy.parquet
#   File  65/193 (building-permits-united-states_0_6_3.snappy.parquet):   2,473 matched → condo_permits_065_building-permits-united-states_0_6_3.snappy.parquet
#   File  66/193 (building-permits-united-states_0_6_4.snappy.parquet):     360 matched → condo_permits_066_building-permits-united-states_0_6_4.snappy.parquet
#   File  67/193 (building-permits-united-states_0_7_0.snappy.parquet):   2,111 matched → condo_permits_067_building-permits-united-states_0_7_0.snappy.parquet
#   File  68/193 (building-permits-united-states_0_7_1.snappy.parquet):   4,070 matched → condo_permits_068_building-permits-united-states_0_7_1.snappy.parquet
#   File  69/193 (building-permits-united-states_0_7_2.snappy.parquet):   3,265 matched → condo_permits_069_building-permits-united-states_0_7_2.snappy.parquet
#   File  70/193 (building-permits-united-states_0_7_3.snappy.parquet):   4,790 matched → condo_permits_070_building-permits-united-states_0_7_3.snappy.parquet
#   File  71/193 (building-permits-united-states_0_7_4.snappy.parquet):   4,156 matched → condo_permits_071_building-permits-united-states_0_7_4.snappy.parquet
#   File  72/193 (building-permits-united-states_0_7_5.snappy.parquet):     295 matched → condo_permits_072_building-permits-united-states_0_7_5.snappy.parquet
#   File  73/193 (building-permits-united-states_1_0_0.snappy.parquet):   3,620 matched → condo_permits_073_building-permits-united-states_1_0_0.snappy.parquet
#   File  74/193 (building-permits-united-states_1_0_1.snappy.parquet):   1,506 matched → condo_permits_074_building-permits-united-states_1_0_1.snappy.parquet
#   File  75/193 (building-permits-united-states_1_0_2.snappy.parquet):   2,867 matched → condo_permits_075_building-permits-united-states_1_0_2.snappy.parquet
#   File  76/193 (building-permits-united-states_1_0_3.snappy.parquet):   2,356 matched → condo_permits_076_building-permits-united-states_1_0_3.snappy.parquet
#   File  77/193 (building-permits-united-states_1_0_4.snappy.parquet):   2,947 matched → condo_permits_077_building-permits-united-states_1_0_4.snappy.parquet
#   File  78/193 (building-permits-united-states_1_1_0.snappy.parquet):   3,171 matched → condo_permits_078_building-permits-united-states_1_1_0.snappy.parquet
#   File  79/193 (building-permits-united-states_1_1_1.snappy.parquet):   7,456 matched → condo_permits_079_building-permits-united-states_1_1_1.snappy.parquet
#   File  80/193 (building-permits-united-states_1_1_2.snappy.parquet):   4,785 matched → condo_permits_080_building-permits-united-states_1_1_2.snappy.parquet
#   File  81/193 (building-permits-united-states_1_1_3.snappy.parquet):   3,450 matched → condo_permits_081_building-permits-united-states_1_1_3.snappy.parquet
#   File  82/193 (building-permits-united-states_1_1_4.snappy.parquet):      64 matched → condo_permits_082_building-permits-united-states_1_1_4.snappy.parquet
#   File  83/193 (building-permits-united-states_1_2_0.snappy.parquet):   1,916 matched → condo_permits_083_building-permits-united-states_1_2_0.snappy.parquet
#   File  84/193 (building-permits-united-states_1_2_1.snappy.parquet):   2,778 matched → condo_permits_084_building-permits-united-states_1_2_1.snappy.parquet
#   File  85/193 (building-permits-united-states_1_2_2.snappy.parquet):   3,204 matched → condo_permits_085_building-permits-united-states_1_2_2.snappy.parquet
#   File  86/193 (building-permits-united-states_1_2_3.snappy.parquet):   3,864 matched → condo_permits_086_building-permits-united-states_1_2_3.snappy.parquet
#   File  87/193 (building-permits-united-states_1_2_4.snappy.parquet):   1,182 matched → condo_permits_087_building-permits-united-states_1_2_4.snappy.parquet
#   File  88/193 (building-permits-united-states_1_3_0.snappy.parquet):   3,047 matched → condo_permits_088_building-permits-united-states_1_3_0.snappy.parquet
#   File  89/193 (building-permits-united-states_1_3_1.snappy.parquet):   4,573 matched → condo_permits_089_building-permits-united-states_1_3_1.snappy.parquet
#   File  90/193 (building-permits-united-states_1_3_2.snappy.parquet):   5,530 matched → condo_permits_090_building-permits-united-states_1_3_2.snappy.parquet
#   File  91/193 (building-permits-united-states_1_3_3.snappy.parquet):   6,797 matched → condo_permits_091_building-permits-united-states_1_3_3.snappy.parquet
#   File  92/193 (building-permits-united-states_1_3_4.snappy.parquet): 0 matched (skipped)
#   File  93/193 (building-permits-united-states_1_4_0.snappy.parquet):   9,474 matched → condo_permits_093_building-permits-united-states_1_4_0.snappy.parquet
#   File  94/193 (building-permits-united-states_1_4_1.snappy.parquet):   9,371 matched → condo_permits_094_building-permits-united-states_1_4_1.snappy.parquet
#   File  95/193 (building-permits-united-states_1_4_2.snappy.parquet):   1,330 matched → condo_permits_095_building-permits-united-states_1_4_2.snappy.parquet
#   File  96/193 (building-permits-united-states_1_4_3.snappy.parquet):   7,959 matched → condo_permits_096_building-permits-united-states_1_4_3.snappy.parquet
#   File  97/193 (building-permits-united-states_1_4_4.snappy.parquet):   4,364 matched → condo_permits_097_building-permits-united-states_1_4_4.snappy.parquet
#   File  98/193 (building-permits-united-states_1_5_0.snappy.parquet):   6,044 matched → condo_permits_098_building-permits-united-states_1_5_0.snappy.parquet
#   File  99/193 (building-permits-united-states_1_5_1.snappy.parquet):   1,969 matched → condo_permits_099_building-permits-united-states_1_5_1.snappy.parquet
#   File 100/193 (building-permits-united-states_1_5_2.snappy.parquet):   3,053 matched → condo_permits_100_building-permits-united-states_1_5_2.snappy.parquet
#   File 101/193 (building-permits-united-states_1_5_3.snappy.parquet):   2,527 matched → condo_permits_101_building-permits-united-states_1_5_3.snappy.parquet
#   File 102/193 (building-permits-united-states_1_5_4.snappy.parquet):   2,380 matched → condo_permits_102_building-permits-united-states_1_5_4.snappy.parquet
#   File 103/193 (building-permits-united-states_1_6_0.snappy.parquet):   2,896 matched → condo_permits_103_building-permits-united-states_1_6_0.snappy.parquet
#   File 104/193 (building-permits-united-states_1_6_1.snappy.parquet):   1,788 matched → condo_permits_104_building-permits-united-states_1_6_1.snappy.parquet
#   File 105/193 (building-permits-united-states_1_6_2.snappy.parquet):   1,581 matched → condo_permits_105_building-permits-united-states_1_6_2.snappy.parquet
#   File 106/193 (building-permits-united-states_1_6_3.snappy.parquet):   2,297 matched → condo_permits_106_building-permits-united-states_1_6_3.snappy.parquet
#   File 107/193 (building-permits-united-states_1_6_4.snappy.parquet):      58 matched → condo_permits_107_building-permits-united-states_1_6_4.snappy.parquet
#   File 108/193 (building-permits-united-states_1_7_0.snappy.parquet):   3,514 matched → condo_permits_108_building-permits-united-states_1_7_0.snappy.parquet
#   File 109/193 (building-permits-united-states_1_7_1.snappy.parquet):   5,348 matched → condo_permits_109_building-permits-united-states_1_7_1.snappy.parquet
#   File 110/193 (building-permits-united-states_1_7_2.snappy.parquet):   3,745 matched → condo_permits_110_building-permits-united-states_1_7_2.snappy.parquet
#   File 111/193 (building-permits-united-states_1_7_3.snappy.parquet):   5,576 matched → condo_permits_111_building-permits-united-states_1_7_3.snappy.parquet
#   File 112/193 (building-permits-united-states_1_7_4.snappy.parquet):     203 matched → condo_permits_112_building-permits-united-states_1_7_4.snappy.parquet
#   File 113/193 (building-permits-united-states_2_0_0.snappy.parquet):   5,286 matched → condo_permits_113_building-permits-united-states_2_0_0.snappy.parquet
#   File 114/193 (building-permits-united-states_2_0_1.snappy.parquet):   3,333 matched → condo_permits_114_building-permits-united-states_2_0_1.snappy.parquet
#   File 115/193 (building-permits-united-states_2_0_2.snappy.parquet):   3,272 matched → condo_permits_115_building-permits-united-states_2_0_2.snappy.parquet
#   File 116/193 (building-permits-united-states_2_0_3.snappy.parquet):   3,099 matched → condo_permits_116_building-permits-united-states_2_0_3.snappy.parquet
#   File 117/193 (building-permits-united-states_2_0_4.snappy.parquet):     303 matched → condo_permits_117_building-permits-united-states_2_0_4.snappy.parquet
#   File 118/193 (building-permits-united-states_2_1_0.snappy.parquet):   4,402 matched → condo_permits_118_building-permits-united-states_2_1_0.snappy.parquet
#   File 119/193 (building-permits-united-states_2_1_1.snappy.parquet):   3,665 matched → condo_permits_119_building-permits-united-states_2_1_1.snappy.parquet
#   File 120/193 (building-permits-united-states_2_1_2.snappy.parquet):   4,015 matched → condo_permits_120_building-permits-united-states_2_1_2.snappy.parquet
#   File 121/193 (building-permits-united-states_2_1_3.snappy.parquet):     161 matched → condo_permits_121_building-permits-united-states_2_1_3.snappy.parquet
#   File 122/193 (building-permits-united-states_2_2_0.snappy.parquet):   1,974 matched → condo_permits_122_building-permits-united-states_2_2_0.snappy.parquet
#   File 123/193 (building-permits-united-states_2_2_1.snappy.parquet):   2,530 matched → condo_permits_123_building-permits-united-states_2_2_1.snappy.parquet
#   File 124/193 (building-permits-united-states_2_2_2.snappy.parquet):   4,661 matched → condo_permits_124_building-permits-united-states_2_2_2.snappy.parquet
#   File 125/193 (building-permits-united-states_2_2_3.snappy.parquet):   7,145 matched → condo_permits_125_building-permits-united-states_2_2_3.snappy.parquet
#   File 126/193 (building-permits-united-states_2_2_4.snappy.parquet):   2,778 matched → condo_permits_126_building-permits-united-states_2_2_4.snappy.parquet
#   File 127/193 (building-permits-united-states_2_2_5.snappy.parquet):      68 matched → condo_permits_127_building-permits-united-states_2_2_5.snappy.parquet
#   File 128/193 (building-permits-united-states_2_3_0.snappy.parquet):   4,596 matched → condo_permits_128_building-permits-united-states_2_3_0.snappy.parquet
#   File 129/193 (building-permits-united-states_2_3_1.snappy.parquet):   2,526 matched → condo_permits_129_building-permits-united-states_2_3_1.snappy.parquet
#   File 130/193 (building-permits-united-states_2_3_2.snappy.parquet):   1,851 matched → condo_permits_130_building-permits-united-states_2_3_2.snappy.parquet
#   File 131/193 (building-permits-united-states_2_3_3.snappy.parquet):     726 matched → condo_permits_131_building-permits-united-states_2_3_3.snappy.parquet
#   File 132/193 (building-permits-united-states_2_3_4.snappy.parquet):   3,175 matched → condo_permits_132_building-permits-united-states_2_3_4.snappy.parquet
#   File 133/193 (building-permits-united-states_2_3_5.snappy.parquet):   2,724 matched → condo_permits_133_building-permits-united-states_2_3_5.snappy.parquet
#   File 134/193 (building-permits-united-states_2_4_0.snappy.parquet):   9,870 matched → condo_permits_134_building-permits-united-states_2_4_0.snappy.parquet
#   File 135/193 (building-permits-united-states_2_4_1.snappy.parquet):   3,593 matched → condo_permits_135_building-permits-united-states_2_4_1.snappy.parquet
#   File 136/193 (building-permits-united-states_2_4_2.snappy.parquet):   8,223 matched → condo_permits_136_building-permits-united-states_2_4_2.snappy.parquet
#   File 137/193 (building-permits-united-states_2_4_3.snappy.parquet):   2,101 matched → condo_permits_137_building-permits-united-states_2_4_3.snappy.parquet
#   File 138/193 (building-permits-united-states_2_4_4.snappy.parquet):     200 matched → condo_permits_138_building-permits-united-states_2_4_4.snappy.parquet
#   File 139/193 (building-permits-united-states_2_5_0.snappy.parquet):   8,123 matched → condo_permits_139_building-permits-united-states_2_5_0.snappy.parquet
#   File 140/193 (building-permits-united-states_2_5_1.snappy.parquet):   4,756 matched → condo_permits_140_building-permits-united-states_2_5_1.snappy.parquet
#   File 141/193 (building-permits-united-states_2_5_2.snappy.parquet):   5,758 matched → condo_permits_141_building-permits-united-states_2_5_2.snappy.parquet
#   File 142/193 (building-permits-united-states_2_5_3.snappy.parquet):   3,614 matched → condo_permits_142_building-permits-united-states_2_5_3.snappy.parquet
#   File 143/193 (building-permits-united-states_2_5_4.snappy.parquet):   4,933 matched → condo_permits_143_building-permits-united-states_2_5_4.snappy.parquet
#   File 144/193 (building-permits-united-states_2_5_5.snappy.parquet):      19 matched → condo_permits_144_building-permits-united-states_2_5_5.snappy.parquet
#   File 145/193 (building-permits-united-states_2_6_0.snappy.parquet):   3,610 matched → condo_permits_145_building-permits-united-states_2_6_0.snappy.parquet
#   File 146/193 (building-permits-united-states_2_6_1.snappy.parquet):   2,731 matched → condo_permits_146_building-permits-united-states_2_6_1.snappy.parquet
#   File 147/193 (building-permits-united-states_2_6_2.snappy.parquet):   3,361 matched → condo_permits_147_building-permits-united-states_2_6_2.snappy.parquet
#   File 148/193 (building-permits-united-states_2_6_3.snappy.parquet):   4,775 matched → condo_permits_148_building-permits-united-states_2_6_3.snappy.parquet
#   File 149/193 (building-permits-united-states_2_6_4.snappy.parquet):     272 matched → condo_permits_149_building-permits-united-states_2_6_4.snappy.parquet
#   File 150/193 (building-permits-united-states_2_6_5.snappy.parquet): 0 matched (skipped)
#   File 151/193 (building-permits-united-states_2_7_0.snappy.parquet):   1,183 matched → condo_permits_151_building-permits-united-states_2_7_0.snappy.parquet
#   File 152/193 (building-permits-united-states_2_7_1.snappy.parquet):   1,987 matched → condo_permits_152_building-permits-united-states_2_7_1.snappy.parquet
#   File 153/193 (building-permits-united-states_2_7_2.snappy.parquet):   3,810 matched → condo_permits_153_building-permits-united-states_2_7_2.snappy.parquet
#   File 154/193 (building-permits-united-states_2_7_3.snappy.parquet): 0 matched (skipped)
#   File 155/193 (building-permits-united-states_3_0_0.snappy.parquet):   2,094 matched → condo_permits_155_building-permits-united-states_3_0_0.snappy.parquet
#   File 156/193 (building-permits-united-states_3_0_1.snappy.parquet):  12,058 matched → condo_permits_156_building-permits-united-states_3_0_1.snappy.parquet
#   File 157/193 (building-permits-united-states_3_0_2.snappy.parquet):   6,885 matched → condo_permits_157_building-permits-united-states_3_0_2.snappy.parquet
#   File 158/193 (building-permits-united-states_3_0_3.snappy.parquet):   4,026 matched → condo_permits_158_building-permits-united-states_3_0_3.snappy.parquet
#   File 159/193 (building-permits-united-states_3_0_4.snappy.parquet):     152 matched → condo_permits_159_building-permits-united-states_3_0_4.snappy.parquet
#   File 160/193 (building-permits-united-states_3_1_0.snappy.parquet):   3,543 matched → condo_permits_160_building-permits-united-states_3_1_0.snappy.parquet
#   File 161/193 (building-permits-united-states_3_1_1.snappy.parquet):  10,955 matched → condo_permits_161_building-permits-united-states_3_1_1.snappy.parquet
#   File 162/193 (building-permits-united-states_3_1_2.snappy.parquet):   6,371 matched → condo_permits_162_building-permits-united-states_3_1_2.snappy.parquet
#   File 163/193 (building-permits-united-states_3_1_3.snappy.parquet):   6,775 matched → condo_permits_163_building-permits-united-states_3_1_3.snappy.parquet
#   File 164/193 (building-permits-united-states_3_1_4.snappy.parquet):   1,534 matched → condo_permits_164_building-permits-united-states_3_1_4.snappy.parquet
#   File 165/193 (building-permits-united-states_3_2_0.snappy.parquet):   3,462 matched → condo_permits_165_building-permits-united-states_3_2_0.snappy.parquet
#   File 166/193 (building-permits-united-states_3_2_1.snappy.parquet):   1,909 matched → condo_permits_166_building-permits-united-states_3_2_1.snappy.parquet
#   File 167/193 (building-permits-united-states_3_2_2.snappy.parquet):   4,016 matched → condo_permits_167_building-permits-united-states_3_2_2.snappy.parquet
#   File 168/193 (building-permits-united-states_3_2_3.snappy.parquet):   4,096 matched → condo_permits_168_building-permits-united-states_3_2_3.snappy.parquet
#   File 169/193 (building-permits-united-states_3_2_4.snappy.parquet):     221 matched → condo_permits_169_building-permits-united-states_3_2_4.snappy.parquet
#   File 170/193 (building-permits-united-states_3_3_0.snappy.parquet):   3,866 matched → condo_permits_170_building-permits-united-states_3_3_0.snappy.parquet
#   File 171/193 (building-permits-united-states_3_3_1.snappy.parquet):   4,317 matched → condo_permits_171_building-permits-united-states_3_3_1.snappy.parquet
#   File 172/193 (building-permits-united-states_3_3_2.snappy.parquet):   2,973 matched → condo_permits_172_building-permits-united-states_3_3_2.snappy.parquet
#   File 173/193 (building-permits-united-states_3_3_3.snappy.parquet):   2,303 matched → condo_permits_173_building-permits-united-states_3_3_3.snappy.parquet
#   File 174/193 (building-permits-united-states_3_3_4.snappy.parquet):     819 matched → condo_permits_174_building-permits-united-states_3_3_4.snappy.parquet
#   File 175/193 (building-permits-united-states_3_4_0.snappy.parquet):   5,994 matched → condo_permits_175_building-permits-united-states_3_4_0.snappy.parquet
#   File 176/193 (building-permits-united-states_3_4_1.snappy.parquet):   8,480 matched → condo_permits_176_building-permits-united-states_3_4_1.snappy.parquet
#   File 177/193 (building-permits-united-states_3_4_2.snappy.parquet):   6,436 matched → condo_permits_177_building-permits-united-states_3_4_2.snappy.parquet
#   File 178/193 (building-permits-united-states_3_4_3.snappy.parquet):   2,580 matched → condo_permits_178_building-permits-united-states_3_4_3.snappy.parquet
#   File 179/193 (building-permits-united-states_3_5_0.snappy.parquet):   2,869 matched → condo_permits_179_building-permits-united-states_3_5_0.snappy.parquet
#   File 180/193 (building-permits-united-states_3_5_1.snappy.parquet):   1,640 matched → condo_permits_180_building-permits-united-states_3_5_1.snappy.parquet
#   File 181/193 (building-permits-united-states_3_5_2.snappy.parquet):   2,895 matched → condo_permits_181_building-permits-united-states_3_5_2.snappy.parquet
#   File 182/193 (building-permits-united-states_3_5_3.snappy.parquet):   3,159 matched → condo_permits_182_building-permits-united-states_3_5_3.snappy.parquet
#   File 183/193 (building-permits-united-states_3_5_4.snappy.parquet):     190 matched → condo_permits_183_building-permits-united-states_3_5_4.snappy.parquet
#   File 184/193 (building-permits-united-states_3_6_0.snappy.parquet):   1,848 matched → condo_permits_184_building-permits-united-states_3_6_0.snappy.parquet
#   File 185/193 (building-permits-united-states_3_6_1.snappy.parquet):   3,796 matched → condo_permits_185_building-permits-united-states_3_6_1.snappy.parquet
#   File 186/193 (building-permits-united-states_3_6_2.snappy.parquet):   4,955 matched → condo_permits_186_building-permits-united-states_3_6_2.snappy.parquet
#   File 187/193 (building-permits-united-states_3_6_3.snappy.parquet):   4,626 matched → condo_permits_187_building-permits-united-states_3_6_3.snappy.parquet
#   File 188/193 (building-permits-united-states_3_6_4.snappy.parquet):     625 matched → condo_permits_188_building-permits-united-states_3_6_4.snappy.parquet
#   File 189/193 (building-permits-united-states_3_7_0.snappy.parquet):   8,725 matched → condo_permits_189_building-permits-united-states_3_7_0.snappy.parquet
#   File 190/193 (building-permits-united-states_3_7_1.snappy.parquet):   2,565 matched → condo_permits_190_building-permits-united-states_3_7_1.snappy.parquet
#   File 191/193 (building-permits-united-states_3_7_2.snappy.parquet):   7,432 matched → condo_permits_191_building-permits-united-states_3_7_2.snappy.parquet
#   File 192/193 (building-permits-united-states_3_7_3.snappy.parquet):   3,555 matched → condo_permits_192_building-permits-united-states_3_7_3.snappy.parquet
#   File 193/193 (building-permits-united-states_3_7_4.snappy.parquet): 0 matched (skipped)
#
# --- SUMMARY ---
# Processed: 193 files
# Total condo-matching permits: 816,900
# Output directory: C:\Users\ngodin\Dropbox\RESEARCH\active_projects\florida_condo\data\dewey_permits_builty\condo_filtered
# Output files: 188

# %%
# Summary of filtered output
filtered_files = sorted(OUTPUT_DIR.glob("*.parquet"))
print(f"✓ Batch processing complete!")
print(f"\nFiltered output summary:")
print(f"  Output directory: {OUTPUT_DIR}")
print(f"  Files created: {len(filtered_files)}")

if filtered_files:
    # Load and combine all filtered files to get summary stats
    all_filtered = []
    for f in filtered_files:
        df = pd.read_parquet(f)
        all_filtered.append(df)
    
    combined = pd.concat(all_filtered, ignore_index=True)
    print(f"  Total condo-matching permits: {len(combined):,}")
    
    # Check date column
    if 'FILE_DATE' in combined.columns:
        dates = pd.to_datetime(combined['FILE_DATE'], errors='coerce')
        print(f"  Date range: {dates.min()} to {dates.max()}")
    
    print(f"  Columns retained: {combined.shape[1]}")
    print(f"\n  Geographic distribution:")
    print(combined['COUNTY'].value_counts().head(10))
# Out:
# ✓ Batch processing complete!
#
# Filtered output summary:
#   Output directory: C:\Users\ngodin\Dropbox\RESEARCH\active_projects\florida_condo\data\dewey_permits_builty\condo_filtered
#   Files created: 188
#   Total condo-matching permits: 816,900
#   Date range: 1955-01-01 00:00:00 to 2025-10-14 00:00:00
#   Columns retained: 90
#
#   Geographic distribution:
# COUNTY
# Broward County         133314
# Pinellas County        123618
# Miami-Dade County      116137
# Lee County             102903
# Palm Beach County       56884
# Indian River County     43207
# Martin County           33451
# Sarasota County         21354
# Hillsborough County     20682
# Charlotte County        20286
# Name: count, dtype: int64

# %%
# Combine all filtered permit files into a single parquet
print("Combining all filtered permits into single file...")

filtered_files = sorted(OUTPUT_DIR.glob("*.parquet"))
all_permits = []

for i, f in enumerate(filtered_files, 1):
    df = pd.read_parquet(f)
    all_permits.append(df)
    if i % 50 == 0:
        print(f"  Loaded {i}/{len(filtered_files)} files...")

combined_permits = pd.concat(all_permits, ignore_index=True)
print(f"\nCombined data:")
print(f"  Total rows: {len(combined_permits):,}")
print(f"  Columns: {combined_permits.shape[1]}")
print(f"  Memory usage: {combined_permits.memory_usage(deep=True).sum() / 1e9:.2f} GB")

# Write combined file
combined_output_path = OUTPUT_DIR.parent / "condo_permits_combined.parquet"
print(f"\nWriting combined file...")
combined_permits.to_parquet(combined_output_path, compression='snappy', index=False)
print(f"✓ Done: {combined_output_path}")
print(f"  File size: {combined_output_path.stat().st_size / 1e9:.2f} GB")
# Out:
# Combining all filtered permits into single file...
#   Loaded 50/188 files...
#   Loaded 100/188 files...
#   Loaded 150/188 files...
#
# Combined data:
#   Total rows: 816,900
#   Columns: 90
#   Memory usage: 6.50 GB
#
# Writing combined file...
# ✓ Done: C:\Users\ngodin\Dropbox\RESEARCH\active_projects\florida_condo\data\dewey_permits_builty\condo_permits_combined.parquet
#   File size: 0.87 GB

# %%
# Check if combined parquet has building_address_attom
combined_path = DATA_ROOT / "data" / "dewey_permits_builty" / "condo_permits_combined.parquet"
combined = pd.read_parquet(combined_path)

print("Columns in combined parquet:")
print(combined.columns.tolist())

if 'building_address_attom' in combined.columns:
    print("\n✓ YES, 'building_address_attom' is in the file")
    print(f"  Non-null count: {combined['building_address_attom'].notna().sum():,}")
    print(f"  Example values:")
    print(combined[['STREET', 'CITY', 'ZIPCODE', 'building_address_attom']].head(3))
else:
    print("\n✗ NO, 'building_address_attom' is NOT in the file")
    print("  (It was used only for filtering/matching, not included in output)")
# Out:
# Columns in combined parquet:
# ['ACCESSORY_STRUCTURE', 'ACCESSORY_STRUCTURE_TYPE', 'AIR_SOURCE_HEAT_PUMP', 'APN', 'APPLICANT_CITY', 'APPLICANT_STATE', 'APPLICANT_ZIPCODE', 'ATTACHED_DETACHED', 'BATH_ITEMS_INSTALLED', 'BATH_REMODEL', 'CITY', 'COMMERCIAL', 'CONDITION', 'CONSTRUCTION_TYPE', 'COUNTY', 'COUNTY_FIPS', 'DATA', 'DEMOLITION', 'DEMO_FULL_PARTIAL', 'DESCRIPTION', 'DWELLING_TYPE', 'EFFICIENCY', 'ELECTRICAL_PANEL_UPGRADE', 'ELECTRICAL_SERVICE_UPGRADE', 'EV_CHARGER', 'EXTERIOR_REMODEL', 'EXTERIOR_REMODEL_TYPE', 'FILE_DATE', 'FINAL_DATE', 'FOUNDATION', 'FOUNDATION_TYPE', 'FOUNDATION_WORK_TYPE', 'GROUND_SOURCE_HEAT_PUMP', 'HEAT_PUMP_WATER_HEATER', 'INDUCTION_STOVE', 'JOB_VALUE', 'JURISDICTION', 'KITCHEN_ITEMS_INSTALLED', 'KITCHEN_REMODEL', 'MULTIFAMILY', 'NEW_ADU', 'NEW_DWELLING', 'NUM_BATHS', 'NUM_BEDS', 'NUM_BUILDINGS', 'NUM_DOORS', 'NUM_FLOORS', 'NUM_ROOMS', 'NUM_UNITS', 'NUM_WINDOWS', 'OWNER_CITY', 'OWNER_STATE', 'OWNER_ZIPCODE', 'PERMIT_DATE', 'PERMIT_NUMBER', 'POOL_SPA', 'POOL_TYPE', 'PUBLIC_WORK', 'RECORD_SUBTYPE_ORIGINAL', 'RECORD_TYPE_ORIGINAL', 'REMODEL_MATERIALS_USED', 'REROOF', 'REROOF_MATERIAL', 'REROOF_TYPE', 'RESIDENTIAL', 'ROOM_ADDITION', 'ROOM_ADDITION_TYPE', 'SITEWORK', 'SITEWORK_TYPE', 'SIZE_SQUARES', 'SIZE_SQUARE_FEET', 'SOLAR', 'SOLAR_BATTERY_STORAGE', 'STATE', 'STATE_FIPS', 'STATUS_NORMALIZED', 'STATUS_ORIGINAL', 'STREET', 'TENANT_IMPROVEMENT', 'TOTAL_FEES', 'UTILITIES', 'UTILITY_CAPACITY', 'UTILITY_TYPE', 'VOLUME', 'WIND', 'WINDOW_DOOR', 'WINDOW_DOOR_TYPE', 'ZIPCODE', 'permit_addr_simple', 'permit_addr_key']
#
# ✗ NO, 'building_address_attom' is NOT in the file
#   (It was used only for filtering/matching, not included in output)

# %%
# Add building_address_attom to the combined permits by merging with condo ref
print("Adding building_address_attom to permits...")

# Load combined permits
combined_path = DATA_ROOT / "data" / "dewey_permits_builty" / "condo_permits_combined.parquet"
permits = pd.read_parquet(combined_path)

print(f"Permits before merge: {len(permits):,} rows")

# Prepare condo ref with just the lookup columns needed
condo_lookup_minimal = condo_ref[['addr_key', 'building_address_attom']].drop_duplicates(subset=['addr_key']).copy()
print(f"Condo lookup table: {len(condo_lookup_minimal):,} unique addresses")

# Merge permits with condo address info
permits_merged = permits.merge(
    condo_lookup_minimal,
    left_on='permit_addr_key',
    right_on='addr_key',
    how='left'
)

print(f"After merge: {len(permits_merged):,} rows")
print(f"building_address_attom populated: {permits_merged['building_address_attom'].notna().sum():,} rows")

# Drop helper columns and duplicate addr_key
permits_merged = permits_merged.drop(columns=['addr_key', 'permit_addr_simple', 'permit_addr_key'])

print(f"\nFinal columns: {permits_merged.shape[1]}")
print(f"Sample:")
print(permits_merged[['STREET', 'CITY', 'ZIPCODE', 'building_address_attom']].head(3))

# Overwrite combined file
print("\nWriting updated parquet...")
permits_merged.to_parquet(combined_path, compression='snappy', index=False)
print(f"✓ Updated: {combined_path}")
print(f"  File size: {combined_path.stat().st_size / 1e9:.2f} GB")
# Out:
# Adding building_address_attom to permits...
# Permits before merge: 816,900 rows
# Condo lookup table: 351,723 unique addresses
# After merge: 816,900 rows
# building_address_attom populated: 816,900 rows
#
# Final columns: 89
# Sample:
#               STREET         CITY ZIPCODE  \
# 0   7832 Collins Ave  Miami Beach   33141
# 1  2463 Pine Tree Dr  Miami Beach   33140
# 2   2625 Collins Ave  Miami Beach   33140
#
#                      building_address_attom
# 0   7832 COLLINS AVE, MIAMI BEACH, FL 33141
# 1  2463 PINE TREE DR, MIAMI BEACH, FL 33140
# 2   2625 COLLINS AVE, MIAMI BEACH, FL 33140
#
# Writing updated parquet...
# ✓ Updated: C:\Users\ngodin\Dropbox\RESEARCH\active_projects\florida_condo\data\dewey_permits_builty\condo_permits_combined.parquet
#   File size: 0.87 GB
