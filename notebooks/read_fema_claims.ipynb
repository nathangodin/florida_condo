# %%
import pandas as pd

# Load the parquet file
df = pd.read_parquet("FimaNfipClaims.parquet")

# Display the first 5 rows
df.head()
# Out:
#    agricultureStructureIndicator                         asOfDate  \
# 0                          False 2020-12-11 16:25:40.587000+00:00
# 1                          False 2020-11-13 14:50:38.288000+00:00
# 2                          False 2022-04-21 19:56:43.051000+00:00
# 3                          False 2020-03-09 19:28:27.372000+00:00
# 4                          False 2020-01-22 16:55:53.194965+00:00
#
#    basementEnclosureCrawlspaceType  policyCount  crsClassificationCode  \
# 0                              0.0            1                    NaN
# 1                              2.0            1                    NaN
# 2                              NaN            1                    8.0
# 3                              NaN            1                    8.0
# 4                              NaN            1                    8.0
#
#    dateOfLoss  elevatedBuildingIndicator elevationCertificateIndicator  \
# 0  2020-09-16                       True                          None
# 1  2020-09-16                      False                          None
# 2  2020-03-05                       True                          None
# 3  2017-06-22                       True                          None
# 4  2016-01-22                      False                          None
#
#   elevationDifference baseFloodElevation  ... rentalPropertyIndicator  state  \
# 0                 4.0               10.0  ...                   False     AL
# 1                 6.0               10.0  ...                   False     AL
# 2                None               None  ...                   False     AL
# 3                None               None  ...                   False     AL
# 4                None               None  ...                   False     AL
#
#             reportedCity reportedZipCode countyCode  censusTract  \
# 0  Currently Unavailable           36542      01003  01003011407
# 1  Currently Unavailable           36542      01003  01003011407
# 2  Currently Unavailable           36066      01001  01001020400
# 3  Currently Unavailable           36066      01001  01001020400
# 4  Currently Unavailable           36067      01001  01001020600
#
#    censusBlockGroupFips  latitude  longitude  \
# 0          010030114072      30.3      -87.7
# 1          010030114073      30.3      -87.7
# 2          010010204001      32.5      -86.4
# 3          010010204001      32.5      -86.4
# 4          010010206001      32.5      -86.5
#
#                                                   id
# 0                 b'\xac++rKqD\x15\x96o\x16/oO\xebl'
# 1  b"\xdd\x95V\x0b\xaf\xd1F\xcb\xb7j\x19\xc5\x8f-...
# 2  b'\xe44\xf7\xe3\xee\xffB\xe4\xab\xc6\xa5\xd4\x...
# 3     b']\xdd\x1b\x02\xa8GK \x87\xbeX\x02\xda\x96 d'
# 4  b'\xa6\xa3\x9c<\x8e\xe5G\xe9\x97_j\xd0f\xa3\xa...
#
# [5 rows x 73 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2709121 entries, 0 to 2709120
# Data columns (total 73 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   agricultureStructureIndicator               bool
#  1   asOfDate                                    datetime64[ns, UTC]
#  2   basementEnclosureCrawlspaceType             float64
#  3   policyCount                                 int16
#  4   crsClassificationCode                       float64
#  5   dateOfLoss                                  object
#  6   elevatedBuildingIndicator                   bool
#  7   elevationCertificateIndicator               object
#  8   elevationDifference                         object
#  9   baseFloodElevation                          object
#  10  ratedFloodZone                              object
#  11  houseWorship                                bool
#  12  locationOfContents                          float64
#  13  lowestAdjacentGrade                         object
#  14  lowestFloorElevation                        object
#  15  numberOfFloorsInTheInsuredBuilding          float64
#  16  nonProfitIndicator                          bool
#  17  obstructionType                             float64
#  18  occupancyType                               float64
#  19  originalConstructionDate                    object
#  20  originalNBDate                              object
#  21  amountPaidOnBuildingClaim                   object
#  22  amountPaidOnContentsClaim                   object
#  23  amountPaidOnIncreasedCostOfComplianceClaim  object
#  24  postFIRMConstructionIndicator               bool
#  25  rateMethod                                  object
#  26  smallBusinessIndicatorBuilding              bool
#  27  totalBuildingInsuranceCoverage              float64
#  28  totalContentsInsuranceCoverage              float64
#  29  yearOfLoss                                  int16
#  30  primaryResidenceIndicator                   bool
#  31  buildingDamageAmount                        float64
#  32  buildingDeductibleCode                      object
#  33  netBuildingPaymentAmount                    object
#  34  buildingPropertyValue                       float64
#  35  causeOfDamage                               object
#  36  condominiumCoverageTypeCode                 object
#  37  contentsDamageAmount                        float64
#  38  contentsDeductibleCode                      object
#  39  netContentsPaymentAmount                    object
#  40  contentsPropertyValue                       float64
#  41  disasterAssistanceCoverageRequired          float64
#  42  eventDesignationNumber                      object
#  43  ficoNumber                                  float64
#  44  floodCharacteristicsIndicator               float64
#  45  floodWaterDuration                          float64
#  46  floodproofedIndicator                       bool
#  47  floodEvent                                  object
#  48  iccCoverage                                 float64
#  49  netIccPaymentAmount                         object
#  50  nfipRatedCommunityNumber                    object
#  51  nfipCommunityNumberCurrent                  object
#  52  nfipCommunityName                           object
#  53  nonPaymentReasonContents                    object
#  54  nonPaymentReasonBuilding                    object
#  55  numberOfUnits                               float64
#  56  buildingReplacementCost                     float64
#  57  contentsReplacementCost                     float64
#  58  replacementCostBasis                        object
#  59  stateOwnedIndicator                         bool
#  60  waterDepth                                  float64
#  61  floodZoneCurrent                            object
#  62  buildingDescriptionCode                     float64
#  63  rentalPropertyIndicator                     bool
#  64  state                                       object
#  65  reportedCity                                object
#  66  reportedZipCode                             object
#  67  countyCode                                  object
#  68  censusTract                                 object
#  69  censusBlockGroupFips                        object
#  70  latitude                                    object
#  71  longitude                                   object
#  72  id                                          object
# dtypes: bool(10), datetime64[ns, UTC](1), float64(22), int16(2), object(38)
# memory usage: 1.3+ GB

# %%
df['buildingDescriptionCode'].value_counts().sort_index()
# 10-11 apartments, 12-13 Co-ops, 14 is commercial building, 15-16 condos,
# Out:
# 1.0     924505
# 2.0       2342
# 3.0        772
# 4.0        411
# 5.0       2415
# 6.0       1425
# 7.0        976
# 8.0      38780
# 9.0        176
# 10.0      2487
# 11.0       358
# 12.0       140
# 13.0       115
# 14.0         8
# 15.0         4
# 16.0         1
# 18.0         2
# 21.0         2
# Name: buildingDescriptionCode, dtype: int64

# %%
num_unique_events = df['floodEvent'].nunique()
print(f"Number of unique flood events: {num_unique_events}")
missing_count = df['floodEvent'].isna().sum()
print(f"Number of missing values in 'floodEvent': {missing_count}")
missing_zip = df['reportedZipCode'].isna().sum()
print(f"Number of missing values in 'reportedZipCode': {missing_zip}")
missing_tract = df['censusTract'].isna().sum()
print(f"Number of missing values in 'censusTract': {missing_tract}")
missing_lat = df['latitude'].isna().sum()
print(f"Number of missing values in 'latitude': {missing_lat}")
# Out:
# Number of unique flood events: 177
# Number of missing values in 'floodEvent': 764610
# Number of missing values in 'reportedZipCode': 0
# Number of missing values in 'censusTract': 137680
# Number of missing values in 'latitude': 41311

# %%
top_50_df = df['floodEvent'].value_counts().head(50).reset_index()
top_50_df.columns = ['floodEvent', 'count']
display(top_50_df)
# Out:
#                      floodEvent   count
# 0                      Flooding  357614
# 1             Hurricane Katrina  208348
# 2               Hurricane Sandy  144848
# 3              Hurricane Harvey   92397
# 4               Hurricane Irene   73685
# 5                 Hurricane Ike   58126
# 6              Hurricane Helene   57738
# 7                 Hurricane Ian   48755
# 8        Tropical Storm Allison   39463
# 9                Hurricane Irma   33339
# 10  December Storm - Nor'easter   30314
# 11     Mid-summer severe storms   30018
# 12                   Nor'easter   28567
# 13                Hurricane Ida   28317
# 14              Hurricane Floyd   27447
# 15             Hurricane Isabel   25835
# 16            Not a named storm   23834
# 17            Hurricane Matthew   21818
# 18             Hurricane Milton   21409
# 19               Hurricane Ivan   20137
# 20               Hurricane Hugo   17253
# 21              Hurricane Isaac   16926
# 22           Hurricane Florence   16918
# 23              Hurricane Wilma   16557
# 24               Hurricane Rita   14662
# 25            Mid-spring storms   14408
# 26             Hurricane Alicia   14072
# 27              Torrential rain   14003
# 28               Hurricane Opal   13779
# 29            Hurricane Georges   13702
# 30               Hurricane Fran   13496
# 31          Tropical Storm Ivan   12749
# 32             Midwest Flooding   12152
# 33             Blizzard of 1993   11727
# 34             Hurricane Andrew   11700
# 35        The "Halloween" Storm   11431
# 36       Tropical Storm Isidore   11113
# 37              Hurricane Elena   11101
# 38     Tropical Storm Claudette   11094
# 39           Tropical Storm Lee   11025
# 40        Tropical Storm Imelda   10940
# 41            Hurricane Frances    9002
# 42         Spring severe storms    8433
# 43          Early summer storms    8354
# 44             Hurricane Gloria    8348
# 45             Hurricane Dennis    8230
# 46           Late spring storms    8132
# 47              Hurricane Sally    8120
# 48             Hurricane Gustav    7663
# 49          Hurricane Josephine    7547

# %%
missing_count_ednum = df['eventDesignationNumber'].isna().sum()
print(f"Number of missing values in 'eventDesignationNumber': {missing_count_ednum}")

missing_count_year = df['yearOfLoss'].isna().sum()
print(f"Number of missing values in 'yearOfLoss': {missing_count_year}")
# Out:
# Number of missing values in 'eventDesignationNumber': 2525643
# Number of missing values in 'yearOfLoss': 0

# %%
# Keep only Florida zip codes
df = df[df['reportedZipCode'].str.startswith(('32', '33'))]

# %%
columns_to_check = [
    'amountPaidOnBuildingClaim',
    'buildingDamageAmount',
    'netBuildingPaymentAmount',
    'buildingReplacementCost',
    'buildingPropertyValue',
    'reportedZipCode',
    'countyCode',
    'censusTract',
    'censusBlockGroupFips'
]

missing_counts = df[columns_to_check].isna().sum().reset_index()
missing_counts.columns = ['column', 'missing_values']
print(missing_counts)
# Out:
#                       column  missing_values
# 0  amountPaidOnBuildingClaim          101392
# 1       buildingDamageAmount          105469
# 2   netBuildingPaymentAmount               0
# 3    buildingReplacementCost          105469
# 4      buildingPropertyValue          105469
# 5            reportedZipCode               0
# 6                 countyCode             578
# 7                censusTract            5780
# 8       censusBlockGroupFips            5780

# %%
# Filter to events from 2000 onward
df_filtered = df[df['yearOfLoss'] >= 2000].copy()

# Create primary ID using eventDesignationNumber or ficoNumber
df_filtered['primaryID'] = df_filtered['eventDesignationNumber'].fillna(df_filtered['ficoNumber'])

# Drop rows where both identifiers are missing
df_filtered = df_filtered[~df_filtered['primaryID'].isna()]

df_filtered['dateOfLoss'] = pd.to_datetime(df_filtered['dateOfLoss'], errors='coerce')

# Function to create grouped summaries
def build_event_summary(df, group_cols):
    return (
        df.groupby(group_cols, dropna=False)
        .agg(
            num_observations=('primaryID', 'size'),
            total_damages=('netBuildingPaymentAmount', 'sum'),
            states_involved=('state', lambda x: ', '.join(sorted(x.dropna().unique()))),
            min_dateOfLoss=('dateOfLoss', 'min'),
            max_dateOfLoss=('dateOfLoss', 'max')
        )
        .reset_index()
    )

# Define groupings
group_id = ['primaryID', 'floodEvent', 'yearOfLoss']
group_zip = group_id + ['reportedZipCode']
group_block = group_id + ['censusBlockGroupFips']

# Build summaries
event_summary_id = build_event_summary(df_filtered, group_id)
event_summary_zip = build_event_summary(df_filtered, group_zip)
event_summary_block = build_event_summary(df_filtered, group_block)

# Clean for Stata export
def clean_for_stata(df):
    df = df.copy()
    df['primaryID'] = df['primaryID'].astype(str).where(df['primaryID'].notna(), None)
    df['total_damages'] = pd.to_numeric(df['total_damages'], errors='coerce')
    df['num_observations'] = df['num_observations'].astype('Int64')

    # Format date columns as strings (ISO 8601) for Stata
    df['min_dateOfLoss'] = df['min_dateOfLoss'].dt.strftime('%Y-%m-%d').where(df['min_dateOfLoss'].notna(), None)
    df['max_dateOfLoss'] = df['max_dateOfLoss'].dt.strftime('%Y-%m-%d').where(df['max_dateOfLoss'].notna(), None)
    
    return df

event_summary_id_clean = clean_for_stata(event_summary_id)
event_summary_zip_clean = clean_for_stata(event_summary_zip)
event_summary_block_clean = clean_for_stata(event_summary_block)

# Export to CSV
event_summary_id_clean.to_csv("event_summary_id.csv", index=False)
event_summary_zip_clean.to_csv("event_summary_zip.csv", index=False)
event_summary_block_clean.to_csv("event_summary_block.csv", index=False)

# Export to Stata
event_summary_id_clean.to_stata("event_summary_id.dta", write_index=False)
event_summary_zip_clean.to_stata("event_summary_zip.dta", write_index=False)
event_summary_block_clean.to_stata("event_summary_block.dta", write_index=False)
