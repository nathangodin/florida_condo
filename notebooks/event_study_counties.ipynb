# %%
import pandas as pd
import statsmodels.api as sm
from linearmodels.panel import PanelOLS
import numpy as np
import matplotlib.pyplot as plt


hoa_df = pd.read_stata('../../final_datasets/master_datasets/master_dataset_assoc_quarter_redfin.dta')
weights = pd.read_stata('../../final_datasets/master_datasets/hoa_redfin_weights.dta')

merged = hoa_df.merge(weights[['assoc_name_final', 'quarter', 'final_weight']], on=['assoc_name_final', 'quarter'], how='left')
# Fill in weights after 2023Q2 with one
cutoff = pd.Timestamp('2023-07-01')          # start of 2023 Q3
mask   = (merged['quarter'] >= cutoff) & merged['final_weight'].isna()
merged.loc[mask, 'final_weight'] = 1.0

# --- Define filters ---
county_filters = {
    "Palm Beach": (merged['mm_fips_county_name_attom'].isin(['PALM BEACH'])),
    "Hillsborough": (merged['mm_fips_county_name_attom'].isin(['HILLSBOROUGH'])),
    "Lee": (merged['mm_fips_county_name_attom'].isin(['LEE'])),
    "Duval": (merged['mm_fips_county_name_attom'].isin(['DUVAL'])),
    "Pinellas": (merged['mm_fips_county_name_attom'].isin(['PINELLAS'])),
    "Collier": (merged['mm_fips_county_name_attom'].isin(['COLLIER'])),
    "Sarasota": (merged['mm_fips_county_name_attom'].isin(['SARASOTA'])),
    "Volusia": (merged['mm_fips_county_name_attom'].isin(['VOLUSIA']))
}

story_filters = {
    "All Buildings": (
        merged['num_stories_final_assoc'].notna()
    )
     ,
#     "<10 Stories": (
#         merged['num_stories_final_assoc'].notna() &
#          (merged['num_stories_final_assoc'] < 10)    
#     )
    "1-4": (
        merged['num_stories_final_assoc'].notna() &
        merged['num_stories_final_assoc'].isin([1, 2, 3, 4])
    )
#     "5-9": (
#         merged['num_stories_final_assoc'].notna() &
#         merged['num_stories_final_assoc'].isin([5, 6, 7, 8, 9])
#     ),
#     "10+": (
#         merged['num_stories_final_assoc'].notna() &
#          (merged['num_stories_final_assoc'] >= 10)
#     )
}


fema_flood_dummies = pd.get_dummies(
    merged['fema_flood_risk_bucket_assoc'], 
    prefix='fema', 
    drop_first=True
)

firststreet_flood_dummies = pd.get_dummies(
    merged['firststreet_risk_cat_assoc'], 
    prefix='firststreet', 
    drop_first=True
)

merged = merged.join(fema_flood_dummies)
merged = merged.join(firststreet_flood_dummies)

merged['units_per_building'] = merged['num_units_final_assoc']/merged['num_bldgs_final_assoc']
merged['units_per_floor'] = merged['units_per_building']/merged['num_stories_final_assoc']

# Extract year and quarter from timestamp
merged['year'] = merged['quarter'].dt.year
merged['month'] = merged['quarter'].dt.month

# Convert month to calendar quarter (1 → Q1, 4 → Q2, etc.)
merged['quarter_num'] = ((merged['month'] - 1) // 3) + 1

# Compute event time relative to 2022Q2 (i.e., April 2022)
merged['event_time'] = (merged['year'] - 2022) * 4 + (merged['quarter_num'] - 2)

event_window = range(-13, 11)
event_dummies = []

for k in event_window:
    if k == -1:
        continue  # baseline
    colname = f'g_{k}_treated'
    merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
    event_dummies.append(colname)
    
# Other covariates
covariates = [
    'gym_redfin_assoc', 'pool_redfin_assoc', 'spa_broad_redfin_assoc',
    'tennis_redfin_assoc', 'garage_redfin_assoc', 'golf_redfin_assoc',
    'boat_redfin_assoc', 'elevator_redfin_assoc', 'view_redfin_assoc',
    'senior_community_redfin_assoc', 'property_age_assoc_qtr',
    'fema_2.0', 'fema_3.0', 'three_miles_coast_assoc', 'log_percap_income_prop_zip'
]

# --- Loop over combinations ---
for y_label, y_cond in county_filters.items():
    for s_label, s_cond in story_filters.items():

        subset = merged[y_cond & s_cond].copy()

        # Set multi-index for panel regression: zip5_attom and quarter
        subset = subset.set_index(['zip5_attom', 'quarter'])
        
        # Dependent and exogenous variables
        y = subset['hoa_sq_ft_assoc_qtr']
        X = subset[event_dummies + covariates]

        # Fit model
        mod = PanelOLS(
            dependent=y,
            exog=X,
#             entity_effects=True,
            time_effects=True,
            weights=subset['final_weight'],
            drop_absorbed=True, 
            check_rank=False
        )
        res = mod.fit(cov_type='clustered', cluster_entity=True)
        print(res.summary)

        import matplotlib.pyplot as plt
        plt.rcParams.update({
            'axes.titlesize': 18,
            'axes.labelsize': 18,
            'xtick.labelsize': 18,
            'ytick.labelsize': 18,
            'legend.fontsize': 18
        })

        # Extract event-time interaction coefficients
        params = res.params
        conf_int = res.conf_int()
        event_times, coefs, ci_low, ci_high = [], [], [], []

        for col in event_dummies:
            k = int(col.split('_')[1])
            event_times.append(k)
            coefs.append(params[col])
            ci_low.append(conf_int.loc[col][0])
            ci_high.append(conf_int.loc[col][1])

        plot_df = pd.DataFrame({
            'event_time': event_times,
            'coef': coefs,
            'ci_lower': ci_low,
            'ci_upper': ci_high
        }).sort_values('event_time')


        # Plot
        plt.figure(figsize=(10, 6))
        plt.axhline(0, color='gray', linestyle='--')
        plt.axvline(0, color='black', linestyle='--', label='Treatment (2022Q2)')
        plt.plot(plot_df['event_time'], plot_df['coef'], marker='o', label='Estimate')
        plt.fill_between(plot_df['event_time'], plot_df['ci_lower'], plot_df['ci_upper'],
                         alpha=0.2, label='95% CI')

        plt.title(f'Event Study: HOA Fee\n{y_label} | {s_label}')
        plt.xlabel('Event Time (Quarters Relative to 2022Q2)', fontsize=18)
        plt.ylabel('Difference in HOA Fee per Sq Ft', fontsize=18)
        plt.legend(loc='upper left')
        plt.grid(True)
        plt.ylim(-0.2, 0.3)
        plt.yticks(np.arange(-0.2, 0.31, 0.1))
        plt.tight_layout()

        # Save with dynamic filename
        # filename = f"output/plot_2021/zip_fe/event_study_{y_label}_{s_label}.png"
        # plt.savefig(filename, dpi=300, bbox_inches='tight')
        plt.show()
        plt.close()

        # print(f"Saved plot: {filename}")
# Out:
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.3010
# Estimator:                    PanelOLS   R-squared (Between):              0.7130
# No. Observations:                 3698   R-squared (Within):               0.1054
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.2852
# Time:                         08:37:57   Log-likelihood                    341.42
# Cov. Estimator:              Clustered
#                                          F-statistic:                      69.991
# Entities:                           41   P-value                           0.0000
# Avg Obs:                        90.195   Distribution:                 F(37,3637)
# Min Obs:                        1.0000
# Max Obs:                        344.00   F-statistic (robust):             3838.7
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                 F(37,3637)
# Avg Obs:                        154.08
# Min Obs:                        93.000
# Max Obs:                        208.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                     0.0275     0.0279     0.9859     0.3243     -0.0272      0.0821
# g_-12_treated                     0.0192     0.0392     0.4894     0.6246     -0.0577      0.0961
# g_-11_treated                     0.0216     0.0501     0.4321     0.6657     -0.0765      0.1198
# g_-10_treated                     0.0044     0.0400     0.1109     0.9117     -0.0740      0.0829
# g_-9_treated                      0.0318     0.0364     0.8723     0.3831     -0.0396      0.1032
# g_-8_treated                      0.0320     0.0378     0.8469     0.3971     -0.0420      0.1060
# g_-7_treated                      0.0039     0.0437     0.0903     0.9281     -0.0818      0.0897
# g_-6_treated                      0.0442     0.0336     1.3183     0.1875     -0.0216      0.1100
# g_-5_treated                      0.0193     0.0214     0.9028     0.3667     -0.0227      0.0614
# g_-4_treated                     -0.0124     0.0450    -0.2757     0.7828     -0.1006      0.0758
# g_-3_treated                     -0.0296     0.0452    -0.6557     0.5120     -0.1183      0.0590
# g_-2_treated                     -0.0017     0.0241    -0.0716     0.9429     -0.0491      0.0456
# g_0_treated                       0.0756     0.0298     2.5344     0.0113      0.0171      0.1341
# g_1_treated                       0.0174     0.0339     0.5139     0.6074     -0.0491      0.0839
# g_2_treated                       0.1135     0.0489     2.3222     0.0203      0.0177      0.2093
# g_3_treated                       0.1060     0.0466     2.2722     0.0231      0.0145      0.1974
# g_4_treated                       0.0411     0.0540     0.7611     0.4466     -0.0648      0.1470
# g_5_treated                       0.0626     0.0223     2.8113     0.0050      0.0189      0.1063
# g_6_treated                       0.0660     0.0446     1.4802     0.1389     -0.0214      0.1535
# g_7_treated                       0.0578     0.0452     1.2802     0.2006     -0.0307      0.1464
# g_8_treated                       0.0766     0.0452     1.6922     0.0907     -0.0121      0.1653
# g_9_treated                       0.0773     0.0480     1.6085     0.1078     -0.0169      0.1715
# g_10_treated                      0.1068     0.0506     2.1106     0.0349      0.0076      0.2061
# gym_redfin_assoc                 -0.0451     0.0424    -1.0630     0.2878     -0.1283      0.0381
# pool_redfin_assoc                 0.0828     0.0313     2.6456     0.0082      0.0214      0.1442
# spa_broad_redfin_assoc            0.0479     0.0257     1.8606     0.0629     -0.0026      0.0983
# tennis_redfin_assoc              -0.0164     0.0170    -0.9670     0.3336     -0.0498      0.0169
# garage_redfin_assoc              -0.0638     0.0338    -1.8883     0.0591     -0.1299      0.0024
# golf_redfin_assoc                -0.0120     0.0309    -0.3903     0.6963     -0.0726      0.0485
# boat_redfin_assoc                -0.1360     0.0329    -4.1298     0.0000     -0.2005     -0.0714
# elevator_redfin_assoc             0.0783     0.0279     2.8062     0.0050      0.0236      0.1331
# view_redfin_assoc                 0.1169     0.0335     3.4898     0.0005      0.0512      0.1826
# senior_community_redfin_assoc     0.0334     0.1324     0.2524     0.8007     -0.2262      0.2930
# property_age_assoc_qtr           -0.0032     0.0016    -2.0166     0.0438     -0.0064  -8.949e-05
# fema_2.0                          0.0453     0.0299     1.5132     0.1303     -0.0134      0.1040
# fema_3.0                          0.1264     0.0219     5.7731     0.0000      0.0835      0.1694
# three_miles_coast_assoc           0.1459     0.0242     6.0163     0.0000      0.0983      0.1934
# log_percap_income_prop_zip        0.0327     0.0060     5.4437     0.0000      0.0209      0.0445
# =================================================================================================
#
# F-test for Poolability: 4.6732
# P-value: 0.0000
# Distribution: F(23,3637)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.2537
# Estimator:                    PanelOLS   R-squared (Between):              0.6610
# No. Observations:                 1975   R-squared (Within):               0.0857
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.2319
# Time:                         08:37:57   Log-likelihood                    1063.1
# Cov. Estimator:              Clustered
#                                          F-statistic:                      40.673
# Entities:                           41   P-value                           0.0000
# Avg Obs:                        48.171   Distribution:                 F(37,1914)
# Min Obs:                        1.0000
# Max Obs:                        201.00   F-statistic (robust):             507.18
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                 F(37,1914)
# Avg Obs:                        82.292
# Min Obs:                        46.000
# Max Obs:                        114.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                     0.0291     0.0227     1.2817     0.2001     -0.0154      0.0737
# g_-12_treated                    -0.0155     0.0317    -0.4888     0.6250     -0.0776      0.0466
# g_-11_treated                    -0.0113     0.0223    -0.5079     0.6116     -0.0550      0.0324
# g_-10_treated                    -0.0089     0.0306    -0.2907     0.7713     -0.0689      0.0511
# g_-9_treated                      0.0027     0.0338     0.0792     0.9369     -0.0636      0.0690
# g_-8_treated                     -0.0159     0.0237    -0.6733     0.5009     -0.0624      0.0305
# g_-7_treated                     -0.0239     0.0489    -0.4894     0.6246     -0.1199      0.0720
# g_-6_treated                      0.0461     0.0300     1.5368     0.1245     -0.0127      0.1049
# g_-5_treated                      0.0139     0.0282     0.4922     0.6226     -0.0414      0.0692
# g_-4_treated                     -0.0409     0.0215    -1.9004     0.0575     -0.0831      0.0013
# g_-3_treated                     -0.0508     0.0497    -1.0222     0.3068     -0.1484      0.0467
# g_-2_treated                     -0.0064     0.0280    -0.2287     0.8192     -0.0612      0.0484
# g_0_treated                       0.0318     0.0243     1.3085     0.1909     -0.0159      0.0795
# g_1_treated                       0.0328     0.0262     1.2519     0.2107     -0.0186      0.0841
# g_2_treated                       0.0804     0.0495     1.6228     0.1048     -0.0168      0.1775
# g_3_treated                       0.0380     0.0377     1.0091     0.3130     -0.0359      0.1119
# g_4_treated                      -0.0115     0.0288    -0.4003     0.6890     -0.0680      0.0449
# g_5_treated                       0.0651     0.0271     2.4067     0.0162      0.0121      0.1182
# g_6_treated                       0.0138     0.0522     0.2641     0.7917     -0.0886      0.1161
# g_7_treated                       0.0070     0.0418     0.1665     0.8678     -0.0751      0.0890
# g_8_treated                       0.0112     0.0472     0.2379     0.8120     -0.0813      0.1038
# g_9_treated                       0.0585     0.0463     1.2632     0.2067     -0.0323      0.1494
# g_10_treated                      0.0457     0.0375     1.2178     0.2235     -0.0279      0.1193
# gym_redfin_assoc                  0.0180     0.0340     0.5297     0.5964     -0.0487      0.0847
# pool_redfin_assoc                 0.0334     0.0267     1.2501     0.2114     -0.0190      0.0859
# spa_broad_redfin_assoc            0.0207     0.0209     0.9937     0.3205     -0.0202      0.0616
# tennis_redfin_assoc               0.0115     0.0130     0.8867     0.3754     -0.0139      0.0370
# garage_redfin_assoc              -0.0226     0.0477    -0.4740     0.6355     -0.1163      0.0710
# golf_redfin_assoc                 0.0665     0.0403     1.6502     0.0991     -0.0125      0.1456
# boat_redfin_assoc                -0.0017     0.0249    -0.0679     0.9459     -0.0506      0.0472
# elevator_redfin_assoc             0.0232     0.0203     1.1406     0.2542     -0.0167      0.0630
# view_redfin_assoc                 0.0558     0.0313     1.7826     0.0748     -0.0056      0.1171
# senior_community_redfin_assoc     0.0669     0.1725     0.3876     0.6984     -0.2714      0.4052
# property_age_assoc_qtr            0.0012     0.0009     1.3068     0.1914     -0.0006      0.0030
# fema_2.0                          0.1184     0.0309     3.8261     0.0001      0.0577      0.1790
# fema_3.0                          0.1319     0.0309     4.2678     0.0000      0.0713      0.1925
# three_miles_coast_assoc           0.0549     0.0210     2.6175     0.0089      0.0138      0.0960
# log_percap_income_prop_zip        0.0236     0.0040     5.8645     0.0000      0.0157      0.0315
# =================================================================================================
#
# F-test for Poolability: 8.7192
# P-value: 0.0000
# Distribution: F(23,1914)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.3684
# Estimator:                    PanelOLS   R-squared (Between):              0.7546
# No. Observations:                  888   R-squared (Within):               0.2163
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.3448
# Time:                         08:37:57   Log-likelihood                    619.67
# Cov. Estimator:              Clustered
#                                          F-statistic:                      24.667
# Entities:                           24   P-value                           0.0000
# Avg Obs:                        37.000   Distribution:                  F(37,827)
# Min Obs:                        2.0000
# Max Obs:                        137.00   F-statistic (robust):          1.597e+14
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                  F(37,827)
# Avg Obs:                        37.000
# Min Obs:                        24.000
# Max Obs:                        50.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                    -0.0529     0.0723    -0.7314     0.4647     -0.1948      0.0891
# g_-12_treated                     0.0563     0.0355     1.5852     0.1133     -0.0134      0.1261
# g_-11_treated                     0.0580     0.0602     0.9637     0.3355     -0.0601      0.1761
# g_-10_treated                     0.0964     0.0312     3.0929     0.0020      0.0352      0.1575
# g_-9_treated                      0.0042     0.0544     0.0767     0.9389     -0.1025      0.1109
# g_-8_treated                     -0.0011     0.0383    -0.0295     0.9765     -0.0764      0.0741
# g_-7_treated                      0.0221     0.0439     0.5043     0.6142     -0.0640      0.1083
# g_-6_treated                      0.0236     0.0354     0.6655     0.5059     -0.0459      0.0931
# g_-5_treated                      0.0004     0.0312     0.0118     0.9906     -0.0608      0.0615
# g_-4_treated                      0.0355     0.0304     1.1683     0.2430     -0.0242      0.0952
# g_-3_treated                     -0.0024     0.0595    -0.0400     0.9681     -0.1192      0.1144
# g_-2_treated                     -0.0857     0.0798    -1.0734     0.2834     -0.2424      0.0710
# g_0_treated                       0.0496     0.0361     1.3759     0.1692     -0.0212      0.1204
# g_1_treated                       0.0779     0.0357     2.1838     0.0293      0.0079      0.1480
# g_2_treated                       0.0814     0.0396     2.0564     0.0401      0.0037      0.1592
# g_3_treated                       0.0374     0.0364     1.0256     0.3054     -0.0341      0.1088
# g_4_treated                       0.1200     0.0309     3.8814     0.0001      0.0593      0.1806
# g_5_treated                       0.1499     0.0401     3.7365     0.0002      0.0712      0.2287
# g_6_treated                       0.0270     0.0650     0.4155     0.6779     -0.1005      0.1545
# g_7_treated                       0.0131     0.0689     0.1904     0.8490     -0.1222      0.1484
# g_8_treated                       0.1788     0.0594     3.0121     0.0027      0.0623      0.2953
# g_9_treated                       0.1407     0.0607     2.3201     0.0206      0.0217      0.2598
# g_10_treated                      0.1555     0.0985     1.5778     0.1150     -0.0379      0.3489
# gym_redfin_assoc                  0.0277     0.0424     0.6544     0.5131     -0.0555      0.1110
# pool_redfin_assoc                 0.0602     0.0272     2.2126     0.0272      0.0068      0.1136
# spa_broad_redfin_assoc            0.0116     0.0471     0.2473     0.8047     -0.0807      0.1040
# tennis_redfin_assoc               0.0146     0.0275     0.5309     0.5956     -0.0394      0.0686
# garage_redfin_assoc               0.0456     0.0181     2.5129     0.0122      0.0100      0.0812
# golf_redfin_assoc                 0.0702     0.0294     2.3849     0.0173      0.0124      0.1279
# boat_redfin_assoc                 0.0371     0.0650     0.5714     0.5679     -0.0904      0.1647
# elevator_redfin_assoc             0.0872     0.0296     2.9410     0.0034      0.0290      0.1453
# view_redfin_assoc                -0.1314     0.0964    -1.3629     0.1733     -0.3206      0.0578
# senior_community_redfin_assoc     0.0517     0.0388     1.3330     0.1829     -0.0244      0.1278
# property_age_assoc_qtr            0.0023     0.0006     3.8952     0.0001      0.0011      0.0035
# fema_2.0                         -0.0656     0.0446    -1.4691     0.1422     -0.1532      0.0220
# fema_3.0                          0.0048     0.0242     0.1973     0.8436     -0.0427      0.0522
# three_miles_coast_assoc           0.0670     0.0345     1.9407     0.0526     -0.0008      0.1347
# log_percap_income_prop_zip        0.0176     0.0046     3.8383     0.0001      0.0086      0.0266
# =================================================================================================
#
# F-test for Poolability: 1.7807
# P-value: 0.0136
# Distribution: F(23,827)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.2744
# Estimator:                    PanelOLS   R-squared (Between):              0.6413
# No. Observations:                  622   R-squared (Within):               0.1716
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.2592
# Time:                         08:37:58   Log-likelihood                    455.61
# Cov. Estimator:              Clustered
#                                          F-statistic:                      14.547
# Entities:                           24   P-value                           0.0000
# Avg Obs:                        25.917   Distribution:                  F(37,561)
# Min Obs:                        2.0000
# Max Obs:                        119.00   F-statistic (robust):          8.975e+14
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                  F(37,561)
# Avg Obs:                        25.917
# Min Obs:                        17.000
# Max Obs:                        36.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                    -0.0457     0.0820    -0.5577     0.5773     -0.2067      0.1153
# g_-12_treated                     0.0501     0.0486     1.0320     0.3025     -0.0453      0.1456
# g_-11_treated                     0.0260     0.0435     0.5990     0.5494     -0.0594      0.1114
# g_-10_treated                     0.0839     0.0387     2.1660     0.0307      0.0078      0.1600
# g_-9_treated                     -0.0218     0.0563    -0.3869     0.6990     -0.1323      0.0888
# g_-8_treated                     -0.0510     0.0435    -1.1733     0.2412     -0.1365      0.0344
# g_-7_treated                     -0.0071     0.0409    -0.1733     0.8625     -0.0874      0.0733
# g_-6_treated                      0.0131     0.0559     0.2338     0.8152     -0.0968      0.1229
# g_-5_treated                     -0.0312     0.0306    -1.0187     0.3088     -0.0913      0.0289
# g_-4_treated                      0.0121     0.0255     0.4766     0.6338     -0.0379      0.0621
# g_-3_treated                     -0.0480     0.0543    -0.8832     0.3775     -0.1546      0.0587
# g_-2_treated                     -0.0305     0.0653    -0.4667     0.6409     -0.1589      0.0979
# g_0_treated                       0.0407     0.0467     0.8729     0.3831     -0.0509      0.1324
# g_1_treated                       0.0584     0.0342     1.7061     0.0885     -0.0088      0.1256
# g_2_treated                       0.0522     0.0352     1.4802     0.1394     -0.0171      0.1214
# g_3_treated                      -0.0268     0.0425    -0.6298     0.5291     -0.1103      0.0567
# g_4_treated                       0.0805     0.0407     1.9774     0.0485      0.0005      0.1604
# g_5_treated                       0.0712     0.0405     1.7596     0.0790     -0.0083      0.1507
# g_6_treated                      -0.0135     0.0361    -0.3750     0.7078     -0.0844      0.0573
# g_7_treated                      -0.0621     0.0840    -0.7393     0.4600     -0.2270      0.1029
# g_8_treated                       0.1012     0.0644     1.5706     0.1168     -0.0254      0.2277
# g_9_treated                       0.0311     0.0529     0.5881     0.5567     -0.0727      0.1349
# g_10_treated                      0.0796     0.1053     0.7564     0.4497     -0.1271      0.2864
# gym_redfin_assoc                  0.0537     0.0447     1.2001     0.2306     -0.0342      0.1416
# pool_redfin_assoc                 0.0304     0.0220     1.3826     0.1673     -0.0128      0.0736
# spa_broad_redfin_assoc           -0.0657     0.0442    -1.4853     0.1380     -0.1525      0.0212
# tennis_redfin_assoc               0.0167     0.0428     0.3900     0.6967     -0.0674      0.1009
# garage_redfin_assoc               0.0379     0.0310     1.2201     0.2229     -0.0231      0.0988
# golf_redfin_assoc                 0.1102     0.0512     2.1508     0.0319      0.0096      0.2108
# boat_redfin_assoc                 0.0589     0.0726     0.8108     0.4178     -0.0838      0.2015
# elevator_redfin_assoc             0.0743     0.0536     1.3869     0.1660     -0.0309      0.1795
# view_redfin_assoc                 0.0267     0.0586     0.4556     0.6489     -0.0883      0.1417
# senior_community_redfin_assoc     0.0165     0.0341     0.4838     0.6287     -0.0505      0.0835
# property_age_assoc_qtr            0.0025     0.0008     3.2409     0.0013      0.0010      0.0040
# fema_2.0                         -0.0587     0.0334    -1.7540     0.0800     -0.1244      0.0070
# fema_3.0                          0.0209     0.0268     0.7823     0.4344     -0.0316      0.0735
# three_miles_coast_assoc           0.0469     0.0473     0.9910     0.3221     -0.0461      0.1399
# log_percap_income_prop_zip        0.0197     0.0069     2.8615     0.0044      0.0062      0.0332
# =================================================================================================
#
# F-test for Poolability: 1.7160
# P-value: 0.0206
# Distribution: F(23,561)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.4475
# Estimator:                    PanelOLS   R-squared (Between):              0.7661
# No. Observations:                  923   R-squared (Within):               0.3189
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.4291
# Time:                         08:37:58   Log-likelihood                    358.93
# Cov. Estimator:              Clustered
#                                          F-statistic:                      29.743
# Entities:                           26   P-value                           0.0000
# Avg Obs:                        35.500   Distribution:                  F(37,862)
# Min Obs:                        1.0000
# Max Obs:                        211.00   F-statistic (robust):          1.101e+15
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                  F(37,862)
# Avg Obs:                        38.458
# Min Obs:                        15.000
# Max Obs:                        71.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                    -0.1507     0.0730    -2.0647     0.0392     -0.2940     -0.0074
# g_-12_treated                     0.0820     0.0441     1.8576     0.0636     -0.0046      0.1687
# g_-11_treated                    -0.1498     0.0508    -2.9465     0.0033     -0.2496     -0.0500
# g_-10_treated                    -0.0846     0.0692    -1.2232     0.2216     -0.2205      0.0512
# g_-9_treated                     -0.0476     0.0738    -0.6451     0.5190     -0.1925      0.0972
# g_-8_treated                      0.0625     0.1042     0.5998     0.5488     -0.1420      0.2670
# g_-7_treated                      0.0060     0.0714     0.0834     0.9336     -0.1341      0.1461
# g_-6_treated                     -0.0270     0.0586    -0.4611     0.6448     -0.1421      0.0880
# g_-5_treated                      0.0400     0.0642     0.6238     0.5329     -0.0859      0.1660
# g_-4_treated                      0.3669     0.1744     2.1039     0.0357      0.0246      0.7092
# g_-3_treated                      0.0412     0.0236     1.7480     0.0808     -0.0051      0.0875
# g_-2_treated                     -0.0114     0.0504    -0.2263     0.8210     -0.1104      0.0876
# g_0_treated                       0.0006     0.0664     0.0092     0.9926     -0.1297      0.1309
# g_1_treated                      -0.0665     0.0403    -1.6512     0.0991     -0.1455      0.0125
# g_2_treated                       0.0776     0.0440     1.7649     0.0779     -0.0087      0.1639
# g_3_treated                       0.0497     0.0625     0.7963     0.4260     -0.0729      0.1723
# g_4_treated                      -0.0790     0.0562    -1.4062     0.1600     -0.1893      0.0313
# g_5_treated                       0.0703     0.0576     1.2217     0.2222     -0.0427      0.1833
# g_6_treated                       0.0462     0.0463     0.9972     0.3189     -0.0447      0.1371
# g_7_treated                       0.1637     0.1073     1.5256     0.1275     -0.0469      0.3743
# g_8_treated                       0.1859     0.0624     2.9792     0.0030      0.0634      0.3084
# g_9_treated                       0.1052     0.0698     1.5079     0.1319     -0.0317      0.2422
# g_10_treated                      0.1881     0.0680     2.7650     0.0058      0.0546      0.3216
# gym_redfin_assoc                  0.0769     0.0189     4.0641     0.0001      0.0397      0.1140
# pool_redfin_assoc                -0.0034     0.0653    -0.0527     0.9580     -0.1316      0.1247
# spa_broad_redfin_assoc            0.0969     0.0378     2.5598     0.0106      0.0226      0.1711
# tennis_redfin_assoc              -0.0205     0.0295    -0.6934     0.4882     -0.0784      0.0375
# garage_redfin_assoc              -0.0760     0.0365    -2.0805     0.0378     -0.1476     -0.0043
# golf_redfin_assoc                 0.1673     0.0420     3.9785     0.0001      0.0847      0.2498
# boat_redfin_assoc                 0.0499     0.0638     0.7817     0.4346     -0.0754      0.1752
# elevator_redfin_assoc            -0.0309     0.0360    -0.8598     0.3901     -0.1015      0.0396
# view_redfin_assoc                 0.0276     0.0242     1.1431     0.2533     -0.0198      0.0751
# senior_community_redfin_assoc    -0.1186     0.0503    -2.3594     0.0185     -0.2172     -0.0199
# property_age_assoc_qtr            0.0050     0.0013     3.8775     0.0001      0.0025      0.0075
# fema_2.0                          0.0254     0.0270     0.9408     0.3471     -0.0276      0.0785
# fema_3.0                          0.0287     0.0365     0.7879     0.4310     -0.0429      0.1004
# three_miles_coast_assoc           0.2164     0.0253     8.5444     0.0000      0.1667      0.2661
# log_percap_income_prop_zip        0.0151     0.0077     1.9585     0.0505  -3.265e-05      0.0303
# =================================================================================================
#
# F-test for Poolability: 1.6892
# P-value: 0.0227
# Distribution: F(23,862)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.4260
# Estimator:                    PanelOLS   R-squared (Between):              0.6722
# No. Observations:                  738   R-squared (Within):               0.2885
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.3906
# Time:                         08:37:59   Log-likelihood                    313.30
# Cov. Estimator:              Clustered
#                                          F-statistic:                      21.733
# Entities:                           26   P-value                           0.0000
# Avg Obs:                        28.385   Distribution:                  F(37,677)
# Min Obs:                        1.0000
# Max Obs:                        211.00   F-statistic (robust):         -4.953e+14
#                                          P-value                           1.0000
# Time periods:                       24   Distribution:                  F(37,677)
# Avg Obs:                        30.750
# Min Obs:                        12.000
# Max Obs:                        59.000
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                    -0.0948     0.0578    -1.6394     0.1016     -0.2084      0.0187
# g_-12_treated                     0.0806     0.0527     1.5297     0.1266     -0.0228      0.1840
# g_-11_treated                    -0.0929     0.0705    -1.3175     0.1881     -0.2313      0.0455
# g_-10_treated                    -0.0811     0.0488    -1.6603     0.0973     -0.1769      0.0148
# g_-9_treated                      0.0117     0.1020     0.1145     0.9088     -0.1885      0.2119
# g_-8_treated                      0.0569     0.0832     0.6836     0.4945     -0.1065      0.2202
# g_-7_treated                      0.0094     0.0866     0.1087     0.9135     -0.1606      0.1794
# g_-6_treated                     -0.0171     0.0794    -0.2147     0.8301     -0.1730      0.1389
# g_-5_treated                      0.0818     0.0738     1.1091     0.2678     -0.0630      0.2266
# g_-4_treated                      0.3445     0.2741     1.2568     0.2093     -0.1937      0.8827
# g_-3_treated                      0.0401     0.0392     1.0234     0.3065     -0.0369      0.1171
# g_-2_treated                     -0.0133     0.0650    -0.2055     0.8373     -0.1409      0.1142
# g_0_treated                      -0.0276     0.0698    -0.3958     0.6924     -0.1648      0.1095
# g_1_treated                      -0.0397     0.0580    -0.6855     0.4933     -0.1536      0.0741
# g_2_treated                       0.0634     0.0537     1.1813     0.2379     -0.0420      0.1688
# g_3_treated                       0.0432     0.0740     0.5840     0.5594     -0.1021      0.1886
# g_4_treated                      -0.0770     0.0729    -1.0573     0.2907     -0.2201      0.0660
# g_5_treated                       0.0393     0.0776     0.5061     0.6129     -0.1131      0.1916
# g_6_treated                       0.0296     0.0575     0.5143     0.6072     -0.0833      0.1424
# g_7_treated                       0.0566     0.0913     0.6196     0.5357     -0.1227      0.2359
# g_8_treated                       0.0455     0.0527     0.8648     0.3874     -0.0578      0.1489
# g_9_treated                       0.0132     0.0624     0.2115     0.8326     -0.1094      0.1358
# g_10_treated                      0.0726     0.0645     1.1247     0.2611     -0.0541      0.1992
# gym_redfin_assoc                  0.0692     0.0181     3.8260     0.0001      0.0337      0.1048
# pool_redfin_assoc                -0.0599     0.0655    -0.9149     0.3606     -0.1885      0.0687
# spa_broad_redfin_assoc            0.0559     0.0348     1.6048     0.1090     -0.0125      0.1242
# tennis_redfin_assoc              -0.0024     0.0274    -0.0892     0.9290     -0.0562      0.0513
# garage_redfin_assoc              -0.0950     0.0200    -4.7590     0.0000     -0.1342     -0.0558
# golf_redfin_assoc                 0.1664     0.0499     3.3368     0.0009      0.0685      0.2643
# boat_redfin_assoc                 0.0684     0.0740     0.9249     0.3554     -0.0768      0.2136
# elevator_redfin_assoc            -0.0925     0.0499    -1.8545     0.0641     -0.1904      0.0054
# view_redfin_assoc                 0.0249     0.0273     0.9119     0.3622     -0.0287      0.0785
# senior_community_redfin_assoc    -0.1171     0.0477    -2.4560     0.0143     -0.2107     -0.0235
# property_age_assoc_qtr            0.0037     0.0015     2.5005     0.0126      0.0008      0.0065
# fema_2.0                          0.0370     0.0376     0.9838     0.3256     -0.0368      0.1108
# fema_3.0                          0.0038     0.0369     0.1043     0.9170     -0.0686      0.0763
# three_miles_coast_assoc           0.2403     0.0508     4.7283     0.0000      0.1405      0.3402
# log_percap_income_prop_zip        0.0251     0.0071     3.5304     0.0004      0.0111      0.0390
# =================================================================================================
#
# F-test for Poolability: 1.7635
# P-value: 0.0154
# Distribution: F(23,677)
#
# Included effects: Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\shared\linalg.py:43: RuntimeWarning: invalid value encountered in divide
#   normed_var = x.var(0) / np.abs(x).max(0)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\1967797946.py:123: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# view_redfin_assoc
#
#   res = mod.fit(cov_type='clustered', cluster_entity=True)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[18], line 124
#     114 mod = PanelOLS(
#     115     dependent=y,
#     116     exog=X,
#    (...)
#     121     check_rank=False
#     122 )
#     123 res = mod.fit(cov_type='clustered', cluster_entity=True)
# --> 124 print(res.summary)
#     126 import matplotlib.pyplot as plt
#     127 plt.rcParams.update({
#     128     'axes.titlesize': 18,
#     129     'axes.labelsize': 18,
#    (...)
#     132     'legend.fontsize': 18
#     133 })
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\results.py:842, in PanelEffectsResults.summary(self)
#     826 @property
#     827 def summary(self) -> Summary:
#     828     """
#     829     Model estimation summary.
#     830
#    (...)
#     839     ``summary.as_html()`` and ``summary.as_latex()``.
#     840     """
# --> 842     smry = super().summary
#     844     is_invalid = np.isfinite(self.f_pooled.stat)
#     845     f_pool = _str(self.f_pooled.stat) if is_invalid else "--"
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\results.py:390, in PanelResults.summary(self)
#     387 f_pval = pval_format(self.f_statistic.pval) if is_invalid else "--"
#     388 f_dist = self.f_statistic.dist_name if is_invalid else "--"
# --> 390 f_robust = _str(self.f_statistic_robust.stat) if is_invalid else "--"
#     391 f_robust_pval = (
#     392     pval_format(self.f_statistic_robust.pval) if is_invalid else "--"
#     393 )
#     394 f_robust_name = self.f_statistic_robust.dist_name if is_invalid else "--"
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\results.py:632, in PanelResults.f_statistic_robust(self)
#     601 r"""
#     602 Joint test of significance for non-constant regressors
#     603
#    (...)
#     627 distribution where df is the residual degree of freedom from the model.
#     628 """
#     629 from linearmodels.panel.model import _deferred_f
#     631 return _deferred_f(
# --> 632     self.params, self.cov, self._debiased, self.df_resid, self._f_info
#     633 )
#
# File ~\anaconda3\lib\functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\results.py:83, in PanelResults.cov(self)
#      79 @cached_property
#      80 def cov(self) -> DataFrame:
#      81     """Estimated covariance of parameters"""
#      82     return DataFrame(
# ---> 83         self._deferred_cov(), columns=self._var_names, index=self._var_names
#      84     )
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\covariance.py:137, in HomoskedasticCovariance.deferred_cov(self)
#     135 def deferred_cov(self) -> linearmodels.typing.data.Float64Array:
#     136     """Covariance calculation deferred until executed"""
# --> 137     return self.cov
#
# File ~\anaconda3\lib\functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~\anaconda3\lib\site-packages\linearmodels\panel\covariance.py:313, in ClusteredCovariance.cov(self)
#     311 x = self._x
#     312 nobs = x.shape[0]
# --> 313 xpxi = inv(x.T @ x / nobs)
#     315 eps = self.eps
#     316 xe = x * eps
#
# File <__array_function__ internals>:180, in inv(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py:552, in inv(a)
#     550 signature = 'D->D' if isComplexType(t) else 'd->d'
#     551 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
import pandas as pd
import statsmodels.api as sm
from linearmodels.panel import PanelOLS
import numpy as np
import matplotlib.pyplot as plt


hoa_df = pd.read_stata('../../final_datasets/master_datasets/master_dataset_assoc_quarter_redfin.dta')
weights = pd.read_stata('../../final_datasets/master_datasets/hoa_redfin_weights.dta')

merged = hoa_df.merge(weights[['assoc_name_final', 'quarter', 'final_weight']], on=['assoc_name_final', 'quarter'], how='left')
# Fill in weights after 2023Q2 with one
cutoff = pd.Timestamp('2023-07-01')          # start of 2023 Q3
mask   = (merged['quarter'] >= cutoff) & merged['final_weight'].isna()
merged.loc[mask, 'final_weight'] = 1.0

# --- Define filters ---
county_filters = {
    "Palm Beach": (merged['mm_fips_county_name_attom'].isin(['PALM BEACH']))
#     ,
#     "Hillsborough": (merged['mm_fips_county_name_attom'].isin(['HILLSBOROUGH'])),
#     "Lee": (merged['mm_fips_county_name_attom'].isin(['LEE'])),
#     "Duval": (merged['mm_fips_county_name_attom'].isin(['DUVAL'])),
#     "Pinellas": (merged['mm_fips_county_name_attom'].isin(['PINELLAS'])),
#     "Collier": (merged['mm_fips_county_name_attom'].isin(['COLLIER'])),
#     "Sarasota": (merged['mm_fips_county_name_attom'].isin(['SARASOTA'])),
#     "Volusia": (merged['mm_fips_county_name_attom'].isin(['VOLUSIA']))
}

story_filters = {
    "All Buildings": (
        merged['num_stories_final_assoc'].notna()
    )
     ,
#     "<10 Stories": (
#         merged['num_stories_final_assoc'].notna() &
#          (merged['num_stories_final_assoc'] < 10)    
#     )
    "1-4": (
        merged['num_stories_final_assoc'].notna() &
        merged['num_stories_final_assoc'].isin([1, 2, 3, 4])
    )
#     "5-9": (
#         merged['num_stories_final_assoc'].notna() &
#         merged['num_stories_final_assoc'].isin([5, 6, 7, 8, 9])
#     ),
#     "10+": (
#         merged['num_stories_final_assoc'].notna() &
#          (merged['num_stories_final_assoc'] >= 10)
#     )
}


fema_flood_dummies = pd.get_dummies(
    merged['fema_flood_risk_bucket_assoc'], 
    prefix='fema', 
    drop_first=True
)

firststreet_flood_dummies = pd.get_dummies(
    merged['firststreet_risk_cat_assoc'], 
    prefix='firststreet', 
    drop_first=True
)

merged = merged.join(fema_flood_dummies)
merged = merged.join(firststreet_flood_dummies)

merged['units_per_building'] = merged['num_units_final_assoc']/merged['num_bldgs_final_assoc']
merged['units_per_floor'] = merged['units_per_building']/merged['num_stories_final_assoc']

# Extract year and quarter from timestamp
merged['year'] = merged['quarter'].dt.year
merged['month'] = merged['quarter'].dt.month

# Convert month to calendar quarter (1 → Q1, 4 → Q2, etc.)
merged['quarter_num'] = ((merged['month'] - 1) // 3) + 1

# Compute event time relative to 2022Q2 (i.e., April 2022)
merged['event_time'] = (merged['year'] - 2022) * 4 + (merged['quarter_num'] - 2)

event_window = range(-13, 11)
event_dummies = []

for k in event_window:
    if k == -1:
        continue  # baseline
    colname = f'g_{k}_treated'
    merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
    event_dummies.append(colname)
    
# Other covariates
covariates = [
    'gym_redfin_assoc', 'pool_redfin_assoc', 'spa_broad_redfin_assoc',
    'tennis_redfin_assoc', 'garage_redfin_assoc', 'golf_redfin_assoc',
    'boat_redfin_assoc', 'elevator_redfin_assoc', 'view_redfin_assoc',
    'senior_community_redfin_assoc', 'property_age_assoc_qtr',
    'fema_2.0', 'fema_3.0', 'three_miles_coast_assoc', 'log_percap_income_prop_zip'
]

# --- Loop over combinations ---
for y_label, y_cond in county_filters.items():
    for s_label, s_cond in story_filters.items():

        subset = merged[y_cond & s_cond].copy()

        # Set multi-index for panel regression: zip5_attom and quarter
        subset = subset.set_index(['zip5_attom', 'quarter'])
        
        # Dependent and exogenous variables
        y = subset['hoa_sq_ft_assoc_qtr']
        X = subset[event_dummies + covariates]

        # Fit model
        mod = PanelOLS(
            dependent=y,
            exog=X,
            entity_effects=True,
            time_effects=True,
            weights=subset['final_weight'],
            drop_absorbed=True, 
            check_rank=False
        )
        res = mod.fit(cov_type='clustered', cluster_entity=True)
        print(res.summary)

        import matplotlib.pyplot as plt
        plt.rcParams.update({
            'axes.titlesize': 18,
            'axes.labelsize': 18,
            'xtick.labelsize': 18,
            'ytick.labelsize': 18,
            'legend.fontsize': 18
        })

        # Extract event-time interaction coefficients
        params = res.params
        conf_int = res.conf_int()
        event_times, coefs, ci_low, ci_high = [], [], [], []

        for col in event_dummies:
            k = int(col.split('_')[1])
            event_times.append(k)
            coefs.append(params[col])
            ci_low.append(conf_int.loc[col][0])
            ci_high.append(conf_int.loc[col][1])

        plot_df = pd.DataFrame({
            'event_time': event_times,
            'coef': coefs,
            'ci_lower': ci_low,
            'ci_upper': ci_high
        }).sort_values('event_time')


        # Plot
        plt.figure(figsize=(10, 6))
        plt.axhline(0, color='gray', linestyle='--')
        plt.axvline(0, color='black', linestyle='--', label='Treatment (2022Q2)')
        plt.plot(plot_df['event_time'], plot_df['coef'], marker='o', label='Estimate')
        plt.fill_between(plot_df['event_time'], plot_df['ci_lower'], plot_df['ci_upper'],
                         alpha=0.2, label='95% CI')

        plt.title(f'Event Study: HOA Fee\n{y_label} | {s_label}')
        plt.xlabel('Event Time (Quarters Relative to 2022Q2)', fontsize=18)
        plt.ylabel('Difference in HOA Fee per Sq Ft', fontsize=18)
        plt.legend(loc='upper left')
        plt.grid(True)
        plt.ylim(-0.2, 0.3)
        plt.yticks(np.arange(-0.2, 0.31, 0.1))
        plt.tight_layout()

        # Save with dynamic filename
        # filename = f"output/plot_2021/zip_fe/event_study_{y_label}_{s_label}.png"
        # plt.savefig(filename, dpi=300, bbox_inches='tight')
        plt.show()
        plt.close()

        # print(f"Saved plot: {filename}")
# Out:
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\AppData\Local\Temp\ipykernel_30804\2410990101.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged[colname] = ((merged['event_time'] == k) & (merged['treated_assoc'] == 1)).astype(int)
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.1191
# Estimator:                    PanelOLS   R-squared (Between):              0.5351
# No. Observations:                 3698   R-squared (Within):               0.1288
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.2490
# Time:                         15:02:18   Log-likelihood                    645.12
# Cov. Estimator:              Clustered
#                                          F-statistic:                      41.906
# Entities:                           41   P-value                           0.0000
# Avg Obs:                        90.195   Distribution:                 F(37,3597)
# Min Obs:                        1.0000
# Max Obs:                        344.00   F-statistic (robust):          3.277e+06
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                 F(37,3597)
# Avg Obs:                        154.08
# Min Obs:                        93.000
# Max Obs:                        208.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                    -0.0106     0.0170    -0.6241     0.5326     -0.0440      0.0227
# g_-12_treated                     0.0258     0.0297     0.8682     0.3853     -0.0324      0.0840
# g_-11_treated                    -0.0189     0.0425    -0.4457     0.6559     -0.1023      0.0644
# g_-10_treated                     0.0031     0.0309     0.1013     0.9193     -0.0575      0.0638
# g_-9_treated                      0.0022     0.0299     0.0733     0.9416     -0.0564      0.0607
# g_-8_treated                      0.0033     0.0352     0.0950     0.9243     -0.0657      0.0724
# g_-7_treated                     -0.0123     0.0371    -0.3328     0.7393     -0.0851      0.0604
# g_-6_treated                      0.0096     0.0254     0.3787     0.7050     -0.0402      0.0594
# g_-5_treated                     -0.0191     0.0221    -0.8663     0.3864     -0.0623      0.0241
# g_-4_treated                     -0.0331     0.0402    -0.8239     0.4100     -0.1120      0.0457
# g_-3_treated                     -0.0435     0.0419    -1.0395     0.2987     -0.1256      0.0386
# g_-2_treated                     -0.0134     0.0275    -0.4884     0.6253     -0.0673      0.0405
# g_0_treated                       0.0467     0.0271     1.7259     0.0845     -0.0064      0.0998
# g_1_treated                       0.0048     0.0275     0.1766     0.8598     -0.0490      0.0587
# g_2_treated                       0.0919     0.0463     1.9852     0.0472      0.0011      0.1826
# g_3_treated                       0.0793     0.0410     1.9370     0.0528     -0.0010      0.1597
# g_4_treated                       0.0358     0.0518     0.6901     0.4902     -0.0658      0.1373
# g_5_treated                       0.0454     0.0229     1.9776     0.0480      0.0004      0.0903
# g_6_treated                       0.0850     0.0395     2.1546     0.0313      0.0077      0.1624
# g_7_treated                       0.0200     0.0348     0.5740     0.5660     -0.0482      0.0881
# g_8_treated                       0.0463     0.0490     0.9449     0.3448     -0.0497      0.1423
# g_9_treated                       0.0488     0.0546     0.8923     0.3723     -0.0584      0.1559
# g_10_treated                      0.0819     0.0499     1.6402     0.1010     -0.0160      0.1797
# gym_redfin_assoc                 -0.0191     0.0414    -0.4604     0.6453     -0.1003      0.0621
# pool_redfin_assoc                 0.0801     0.0272     2.9455     0.0032      0.0268      0.1334
# spa_broad_redfin_assoc            0.0320     0.0228     1.4021     0.1610     -0.0127      0.0766
# tennis_redfin_assoc              -0.0269     0.0232    -1.1600     0.2461     -0.0724      0.0186
# garage_redfin_assoc              -0.0725     0.0363    -1.9989     0.0457     -0.1436     -0.0014
# golf_redfin_assoc                -0.0069     0.0322    -0.2135     0.8310     -0.0701      0.0563
# boat_redfin_assoc                -0.1078     0.0403    -2.6767     0.0075     -0.1868     -0.0288
# elevator_redfin_assoc             0.0499     0.0279     1.7845     0.0744     -0.0049      0.1046
# view_redfin_assoc                 0.0872     0.0225     3.8830     0.0001      0.0432      0.1313
# senior_community_redfin_assoc    -0.0283     0.1418    -0.1992     0.8421     -0.3063      0.2498
# property_age_assoc_qtr           -0.0032     0.0016    -2.0109     0.0444     -0.0064  -8.052e-05
# fema_2.0                          0.0394     0.0255     1.5432     0.1229     -0.0106      0.0894
# fema_3.0                          0.0996     0.0337     2.9609     0.0031      0.0337      0.1656
# three_miles_coast_assoc           0.0539     0.0380     1.4202     0.1557     -0.0205      0.1284
# log_percap_income_prop_zip        0.0431     0.0067     6.4235     0.0000      0.0299      0.0563
# =================================================================================================
#
# F-test for Poolability: 12.181
# P-value: 0.0000
# Distribution: F(63,3597)
#
# Included effects: Entity, Time
# C:\Users\ngodin\anaconda3\lib\site-packages\linearmodels\panel\model.py:1260: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     hoa_sq_ft_assoc_qtr   R-squared:                        0.1066
# Estimator:                    PanelOLS   R-squared (Between):              0.3762
# No. Observations:                 1975   R-squared (Within):               0.1243
# Date:                 Thu, Aug 14 2025   R-squared (Overall):              0.1883
# Time:                         15:02:18   Log-likelihood                    1235.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                      29.202
# Entities:                           41   P-value                           0.0000
# Avg Obs:                        48.171   Distribution:                 F(37,1874)
# Min Obs:                        1.0000
# Max Obs:                        201.00   F-statistic (robust):             754.73
#                                          P-value                           0.0000
# Time periods:                       24   Distribution:                 F(37,1874)
# Avg Obs:                        82.292
# Min Obs:                        46.000
# Max Obs:                        114.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# g_-13_treated                     0.0148     0.0206     0.7180     0.4729     -0.0256      0.0552
# g_-12_treated                     0.0078     0.0297     0.2641     0.7917     -0.0504      0.0661
# g_-11_treated                    -0.0189     0.0242    -0.7837     0.4333     -0.0663      0.0284
# g_-10_treated                     0.0084     0.0290     0.2907     0.7713     -0.0485      0.0653
# g_-9_treated                     -0.0087     0.0319    -0.2722     0.7855     -0.0711      0.0538
# g_-8_treated                     -0.0212     0.0240    -0.8805     0.3787     -0.0683      0.0260
# g_-7_treated                     -0.0128     0.0449    -0.2839     0.7765     -0.1009      0.0754
# g_-6_treated                      0.0396     0.0262     1.5124     0.1306     -0.0118      0.0910
# g_-5_treated                      0.0114     0.0290     0.3910     0.6959     -0.0456      0.0683
# g_-4_treated                     -0.0428     0.0258    -1.6632     0.0964     -0.0934      0.0077
# g_-3_treated                     -0.0350     0.0471    -0.7430     0.4576     -0.1274      0.0574
# g_-2_treated                      0.0042     0.0307     0.1383     0.8900     -0.0559      0.0644
# g_0_treated                       0.0169     0.0244     0.6938     0.4879     -0.0309      0.0648
# g_1_treated                       0.0189     0.0254     0.7457     0.4559     -0.0308      0.0686
# g_2_treated                       0.0690     0.0519     1.3300     0.1837     -0.0328      0.1708
# g_3_treated                       0.0358     0.0386     0.9277     0.3537     -0.0399      0.1114
# g_4_treated                      -0.0016     0.0287    -0.0551     0.9560     -0.0579      0.0547
# g_5_treated                       0.0531     0.0275     1.9291     0.0539     -0.0009      0.1071
# g_6_treated                       0.0445     0.0488     0.9134     0.3611     -0.0511      0.1402
# g_7_treated                      -0.0080     0.0344    -0.2336     0.8154     -0.0755      0.0594
# g_8_treated                      -0.0002     0.0475    -0.0051     0.9959     -0.0934      0.0929
# g_9_treated                       0.0736     0.0448     1.6421     0.1007     -0.0143      0.1615
# g_10_treated                      0.0298     0.0304     0.9804     0.3270     -0.0298      0.0894
# gym_redfin_assoc                  0.0687     0.0328     2.0968     0.0361      0.0044      0.1329
# pool_redfin_assoc                 0.0532     0.0271     1.9671     0.0493      0.0002      0.1063
# spa_broad_redfin_assoc            0.0197     0.0204     0.9660     0.3342     -0.0203      0.0598
# tennis_redfin_assoc              -0.0101     0.0173    -0.5815     0.5610     -0.0441      0.0239
# garage_redfin_assoc              -0.0299     0.0443    -0.6764     0.4989     -0.1168      0.0569
# golf_redfin_assoc                 0.0518     0.0413     1.2535     0.2102     -0.0292      0.1328
# boat_redfin_assoc                -0.0052     0.0280    -0.1867     0.8520     -0.0601      0.0496
# elevator_redfin_assoc             0.0020     0.0211     0.0969     0.9228     -0.0393      0.0434
# view_redfin_assoc                 0.0381     0.0331     1.1492     0.2506     -0.0269      0.1030
# senior_community_redfin_assoc     0.0535     0.1782     0.3000     0.7642     -0.2960      0.4029
# property_age_assoc_qtr            0.0023     0.0009     2.6753     0.0075      0.0006      0.0040
# fema_2.0                          0.0823     0.0304     2.7039     0.0069      0.0226      0.1420
# fema_3.0                          0.0850     0.0274     3.0988     0.0020      0.0312      0.1387
# three_miles_coast_assoc          -0.0113     0.0277    -0.4068     0.6842     -0.0655      0.0430
# log_percap_income_prop_zip        0.0236     0.0038     6.1383     0.0000      0.0160      0.0311
# =================================================================================================
#
# F-test for Poolability: 9.3883
# P-value: 0.0000
# Distribution: F(63,1874)
#
# Included effects: Entity, Time
